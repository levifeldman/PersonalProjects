# %% [markdown]
# # Welcome to Sentiment Classification. A personal project by Levi Feldman.
#
# Sentiment Classification refers to figuring out if a group of text (i.e a movie review) is more positive then negative or more negative then positive. Whether or not the author of said text meant to be positive or negative.
#
# This can be very usefull for example, when someone comes out with a movie and millions of people watch it. The movie maker wants to know around how many people liked or disliked his movie but it would take him months to read through every review and see if they are positive or negative. So that's where deep learning comes in, we will try to create a network that can predict with at least around an 85% accuracy whether or not a given review is positive or negative.
#
# In this project I will be building a neural network from scratch to analzye movie reviews and classify them by sentiment. I will be training the network using 25,000 labeled movie reviews from IMDB.
#
# This notebook is an example of the process of solving a problem with deep learning by:
# - Developing a predictive theory
# - Proccessing the data
# - Building a network
# - Optimization: Reducing noise and analyzing inefficiencys.

# %% [markdown]
# # Looking at the datasets
#
# By looking at the data I will try to figure out the best way for a neural network to learn how to differentiate between positive reviews and negative reviews.
#
#
# The reviews come in a .txt document separated by newlines. First we will process all of them into a list  - "reviews"

# %%
g = open('reviews.txt','r') # put reviews into a list
reviews = list(map(lambda x:x[:-1],g.readlines()))
g.close()

g = open('labels.txt','r') # put labels into a list
labels = list(map(lambda x:x[:-1].upper(),g.readlines()))
g.close()

### Clean data, make reviews lowercase ###
for i in range(len(reviews)):
    reviews[i] = reviews[i].lower()

print("There are {} reviews and {} labels".format(len(reviews), len(labels)))
# Out:
# There are 25000 reviews and 25000 labels

# %% [markdown]
# Samples:

# %%
print(reviews[0])
reviews[1]
# Out:
# bromwell high is a cartoon comedy . it ran at the same time as some other programs about school life  such as  teachers  . my   years in the teaching profession lead me to believe that bromwell high  s satire is much closer to reality than is  teachers  . the scramble to survive financially  the insightful students who can see right through their pathetic teachers  pomp  the pettiness of the whole situation  all remind me of the schools i knew and their students . when i saw the episode in which a student repeatedly tried to burn down the school  i immediately recalled . . . . . . . . . at . . . . . . . . . . high . a classic line inspector i  m here to sack one of your teachers . student welcome to bromwell high . i expect that many adults of my age think that bromwell high is far fetched . what a pity that it isn  t
# 'story of a man who has unnatural feelings for a pig . starts out with a opening scene that is a terrific example of absurd comedy . a formal orchestra audience is turned into an insane  violent mob by the crazy chantings of it  s singers . unfortunately it stays absurd the whole time with no general narrative eventually making it just too off putting . even those from the era should be turned off . the cryptic dialogue would make shakespeare seem easy to a third grader . on a technical level it  s better than you might think with some good cinematography by future great vilmos zsigmond . future stars sally kirkland and frederic forrest can be seen briefly .  '

# %%
labels[5]
# Out:
# 'NEGATIVE'

# %%
labels[6]
# Out:
# 'POSITIVE'

# %%
def show_review_and_label(i):
    print(labels[i] + "\t:\t" + reviews[i][:80] + "..")

print("    Labels\t:\tReviews\n")
show_review_and_label(12816)
show_review_and_label(21934)
show_review_and_label(5297)
show_review_and_label(4998)
show_review_and_label(6267)
show_review_and_label(2137)
# Out:
#     Labels	:	Reviews
#
# POSITIVE	:	adrian pasdar is excellent is this film . he makes a fascinating woman .  ..
# POSITIVE	:	excellent episode movie ala pulp fiction .  days   suicides . it doesnt get more..
# NEGATIVE	:	if you haven  t seen this  it  s terrible . it is pure trash . i saw this about ..
# POSITIVE	:	this schiffer guy is a real genius  the movie is of excellent quality and both e..
# NEGATIVE	:	comment this movie is impossible . is terrible  very improbable  bad interpretat..
# NEGATIVE	:	this movie is terrible but it has some good effects .  ..

# %% [markdown]
# # Predictive theory:
#
# So looking at the data, naturally I see that positive words like "excellent", and "fascinating" are mentioned more often in the positive reviews then in the negative reviews. At the same time negative words like "bad", and "terrible" are mentioned way more in the negative reviews then in the positive reviews.
#  - Maybe our network will be able to learn by associating a given amount of "importance", or "lean" for every word. Either a lean towards positive, or a lean towards negative. Maybe when the network sees that a certain word is only or mostly being used in reviews with a positive sentiment for example, the network can then learn that the value of the "importance", or "lean" of this word is a strong positive. Then when predicting a sentiment, the network can look at the "lean", or "importance" of every word in a review, and after taking all of the values into account, output where the review as a whole leaned to more.
#
# Next I will try to validate my theory by counting the amount of times words occur in positive reviews and in negative reviews.

# %%
import numpy as np
from collections import Counter

positive_word_count = Counter()
negative_word_count = Counter()
total_word_count = Counter()

# %%
### Counting the amount of times each word appears in positive reviews and in negative reviews.

for i in range(len(reviews)):
    if labels[i] == 'POSITIVE':
        for word in reviews[i].split(' '):
            positive_word_count[word] += 1
            total_word_count[word] += 1
    elif labels[i] == 'NEGATIVE':
        for word in reviews[i].split(' '):
            negative_word_count[word] += 1
            total_word_count[word] += 1

# %%
### Most common words in positive reviews ###
positive_word_count.most_common()[:30]
# Out:
# [('', 550468),
#  ('the', 173324),
#  ('.', 159654),
#  ('and', 89722),
#  ('a', 83688),
#  ('of', 76855),
#  ('to', 66746),
#  ('is', 57245),
#  ('in', 50215),
#  ('br', 49235),
#  ('it', 48025),
#  ('i', 40743),
#  ('that', 35630),
#  ('this', 35080),
#  ('s', 33815),
#  ('as', 26308),
#  ('with', 23247),
#  ('for', 22416),
#  ('was', 21917),
#  ('film', 20937),
#  ('but', 20822),
#  ('movie', 19074),
#  ('his', 17227),
#  ('on', 17008),
#  ('you', 16681),
#  ('he', 16282),
#  ('are', 14807),
#  ('not', 14272),
#  ('t', 13720),
#  ('one', 13655)]

# %%
### Most common words in negative reviews ###
negative_word_count.most_common()[:30]
# Out:
# [('', 561462),
#  ('.', 167538),
#  ('the', 163389),
#  ('a', 79321),
#  ('and', 74385),
#  ('of', 69009),
#  ('to', 68974),
#  ('br', 52637),
#  ('is', 50083),
#  ('it', 48327),
#  ('i', 46880),
#  ('in', 43753),
#  ('this', 40920),
#  ('that', 37615),
#  ('s', 31546),
#  ('was', 26291),
#  ('movie', 24965),
#  ('for', 21927),
#  ('but', 21781),
#  ('with', 20878),
#  ('as', 20625),
#  ('t', 20361),
#  ('film', 19218),
#  ('you', 17549),
#  ('on', 17192),
#  ('not', 16354),
#  ('have', 15144),
#  ('are', 14623),
#  ('be', 14541),
#  ('he', 13856)]

# %%
### Most common words in all ###
total_word_count.most_common()[:30]
# Out:
# [('', 1111930),
#  ('the', 336713),
#  ('.', 327192),
#  ('and', 164107),
#  ('a', 163009),
#  ('of', 145864),
#  ('to', 135720),
#  ('is', 107328),
#  ('br', 101872),
#  ('it', 96352),
#  ('in', 93968),
#  ('i', 87623),
#  ('this', 76000),
#  ('that', 73245),
#  ('s', 65361),
#  ('was', 48208),
#  ('as', 46933),
#  ('for', 44343),
#  ('with', 44125),
#  ('movie', 44039),
#  ('but', 42603),
#  ('film', 40155),
#  ('you', 34230),
#  ('on', 34200),
#  ('t', 34081),
#  ('not', 30626),
#  ('he', 30138),
#  ('are', 29430),
#  ('his', 29374),
#  ('have', 27731)]

# %% [markdown]
# There are a lot of neutral words like "the", and "or". It's hard to validate the theory. What I'll do is calculate the ratios of how much  more a word is used in positive reviews then in negative reviews to really see if words like "excellent", and "amazing" are used more in positive reviews then negative reviews.

# %%
PN_ratios = Counter()

### Just taking words that are appear at least 100 times ###
common_words = []
for word,cnt in total_word_count.items():
    if cnt > 100:
        common_words.append(word)


for word in common_words:
    if negative_word_count[word] != 0: ### Making sure not to divide by zero ###
        PN_ratios[word] = positive_word_count[word] / float(negative_word_count[word])
    else:
        PN_ratios[word] = positive_word_count[word]

# %%
print("Positive-to-negative ratio for 'the' = {}".format(PN_ratios["the"]))
print("Positive-to-negative ratio for 'and' = {}".format(PN_ratios["and"]))
print("Positive-to-negative ratio for 'amazing' = {}".format(PN_ratios["amazing"]))
print("Positive-to-negative ratio for 'excellent' = {}".format(PN_ratios["excellent"]))
print("Poitives-to-negative ratio for 'terrible' = {}".format(PN_ratios["terrible"]))
print("Positive-to-negative ratio for 'bad' = {}".format(PN_ratios["bad"]))
# Out:
# Positive-to-negative ratio for 'the' = 1.0608058070004713
# Positive-to-negative ratio for 'and' = 1.2061840424816832
# Positive-to-negative ratio for 'amazing' = 4.038167938931298
# Positive-to-negative ratio for 'excellent' = 4.337628865979381
# Poitives-to-negative ratio for 'terrible' = 0.17757009345794392
# Positive-to-negative ratio for 'bad' = 0.25766788271855157

# %% [markdown]
# Looking at these ratios:
# - Words like "excellent", that would be expected to show up more often in positive reviews have a high value greater than 1. The stronger the positive "importance", the greater the value of its P/N-ratio.
# - Words like "bad" and "terrible" that would be expected to show up more often in negative reviews have a ratio between 1 and 0, the stronger the negative the closer to 0.
# - Neutral words like "the" and "what", have ratios that center around 1
#
#
# So we are starting to see that our theory of how the network might learn can work. The amount of times different words appear in a review is a very good way of telling if the review is positive or negative.
#
# However, the ratios we got are not the best to work with because when comparing, the absolute value of the ratios of the words that appear more positive is much greater then the absolute value of those that appear more negative. When working with absolute values, it is much easier to center them around 0. Therefore I will convert all of these ratios to logarithms so that two words that are equally as strong going in opposite directions will be the same distance from 0.

# %%
for i in PN_ratios:
    PN_ratios[i] = np.log(PN_ratios[i])

# %%
PN_ratios.most_common()
# Out:
# [('paulie', 4.7706846244656651),
#  ('edie', 4.6913478822291435),
#  ('felix', 3.3758795736778655),
#  ('polanski', 3.0056826044071592),
#  ('matthau', 2.924504764265623),
#  ('victoria', 2.7500144002012421),
#  ('mildred', 2.7362210780689065),
#  ('gandhi', 2.6567569067146595),
#  ('flawless', 2.5563656137701454),
#  ('superbly', 2.3470368555648795),
#  ('perfection', 2.2284771208403238),
#  ('astaire', 2.2141741356499924),
#  ('voight', 2.1102132003465894),
#  ('captures', 2.0794415416798357),
#  ('wonderfully', 2.0485643031153966),
#  ('brosnan', 2.0193376176101303),
#  ('powell', 2.0175661379617482),
#  ('lily', 1.9810014688665833),
#  ('bakshi', 1.9636097261547143),
#  ('lincoln', 1.9459101490553132),
#  ('lemmon', 1.9148195619852821),
#  ('breathtaking', 1.8925641683500207),
#  ('refreshing', 1.891548939836426),
#  ('bourne', 1.8870696490323797),
#  ('flynn', 1.8484548129046001),
#  ('homer', 1.8382794848629478),
#  ('soccer', 1.8268507890393251),
#  ('delightful', 1.8262456452992242),
#  ('andrews', 1.8230120127321594),
#  ('elvira', 1.7841548698428356),
#  ('beautifully', 1.7784436932522829),
#  ('gripping', 1.7609878105613013),
#  ('underrated', 1.747956846569662),
#  ('sadness', 1.7206635475443246),
#  ('superb', 1.7189076208420597),
#  ('delight', 1.7122952978738082),
#  ('welles', 1.693024628542366),
#  ('macy', 1.6817585740137264),
#  ('timeless', 1.6805338341178306),
#  ('hartley', 1.6700625342505353),
#  ('sinatra', 1.6643145226599347),
#  ('unforgettable', 1.6602963296675914),
#  ('touching', 1.6514021115331325),
#  ('favorites', 1.6486586255873816),
#  ('extraordinary', 1.6445292322453706),
#  ('sullivan', 1.6411866107486806),
#  ('stewart', 1.6249021381316819),
#  ('brilliantly', 1.6191467265610613),
#  ('palma', 1.6094379124341003),
#  ('friendship', 1.588384503236268),
#  ('ritter', 1.5830046553659449),
#  ('magnificent', 1.5686159179138452),
#  ('jackie', 1.5686159179138452),
#  ('wonderful', 1.5680329974659779),
#  ('finest', 1.5668782980153044),
#  ('tremendous', 1.5629178967992075),
#  ('pleasantly', 1.5339303599259553),
#  ('mann', 1.5339303599259553),
#  ('freedom', 1.5321047090309301),
#  ('sidney', 1.5246966839790097),
#  ('terrific', 1.515408962785824),
#  ('nancy', 1.5121746070088933),
#  ('fantastic', 1.5117638297004306),
#  ('marvelous', 1.5079014932146777),
#  ('noir', 1.5069971068796089),
#  ('outstanding', 1.5040773967762742),
#  ('ruth', 1.5040773967762742),
#  ('marie', 1.5040773967762742),
#  ('stanwyck', 1.4739999415389962),
#  ('splendid', 1.4696759700589417),
#  ('widmark', 1.4689860769650041),
#  ('excellent', 1.4673278545675326),
#  ('tender', 1.4622802680978126),
#  ('exceptional', 1.455287232606842),
#  ('gentle', 1.452252328911688),
#  ('chan', 1.4484261422268967),
#  ('poignant', 1.4350845252893227),
#  ('captivating', 1.4288539755386864),
#  ('fisher', 1.4255150742731719),
#  ('davies', 1.4255150742731719),
#  ('chilling', 1.4161473242695717),
#  ('darker', 1.4078005663408544),
#  ('gem', 1.4072010459392044),
#  ('april', 1.3987168811184478),
#  ('amazing', 1.3957911086571477),
#  ('blake', 1.3862943611198906),
#  ('overlooked', 1.366876275262789),
#  ('ralph', 1.3609765531356006),
#  ('kelly', 1.3574739225843986),
#  ('cole', 1.3485540331370436),
#  ('bette', 1.346448452572691),
#  ('hoffman', 1.3403846598158127),
#  ('shines', 1.3366974199805186),
#  ('winters', 1.3277981544382822),
#  ('vivid', 1.3188530803243581),
#  ('notch', 1.3185761870649397),
#  ('giallo', 1.3137236682850553),
#  ('pitt', 1.3103084541419687),
#  ('powerful', 1.3075134832667763),
#  ('psychiatrist', 1.3062516534463542),
#  ('remarkable', 1.3034067013141228),
#  ('garbo', 1.3034067013141228),
#  ('portrait', 1.3022112439093492),
#  ('gritty', 1.2992829841302609),
#  ('innocence', 1.2992829841302609),
#  ('ensemble', 1.2964380319980295),
#  ('holly', 1.2953225829141639),
#  ('panic', 1.2919836816486494),
#  ('burns', 1.2851982442485219),
#  ('philip', 1.2809338454620642),
#  ('carol', 1.2809338454620642),
#  ('barbara', 1.2767321586083644),
#  ('rural', 1.2762934659055623),
#  ('stunning', 1.2734150130480371),
#  ('brooklyn', 1.2712250313351035),
#  ('favorite', 1.2705924916673317),
#  ('builds', 1.2697605448639391),
#  ('appreciated', 1.2692378056988731),
#  ('unfolds', 1.258954938743289),
#  ('favourite', 1.2547180033311713),
#  ('perfect', 1.2495475316413938),
#  ('von', 1.2492725635555995),
#  ('journey', 1.2469149986129449),
#  ('bond', 1.2452157628599851),
#  ('brilliant', 1.2324522756478047),
#  ('recommended', 1.2253639943072534),
#  ('crafted', 1.2222262446352863),
#  ('troubled', 1.2219913098286144),
#  ('consequences', 1.221672381425337),
#  ('daniel', 1.2205021062771466),
#  ('alexander', 1.2110902720948),
#  ('prince', 1.2083112059245342),
#  ('boxing', 1.2074151485169087),
#  ('perfectly', 1.2039728043259361),
#  ('haunting', 1.2001920814860301),
#  ('cinderella', 1.1984017592764806),
#  ('curtis', 1.1948403207626634),
#  ('emotions', 1.1862339799885544),
#  ('subtle', 1.1831696766961728),
#  ('daughters', 1.176777061517446),
#  ('courage', 1.1720397572229269),
#  ('dentist', 1.1700712526502546),
#  ('draws', 1.1676051601550612),
#  ('rare', 1.1661225801948385),
#  ('nominated', 1.1596068013709517),
#  ('loved', 1.1592944098376925),
#  ('cried', 1.1564318595569358),
#  ('everyday', 1.1553076323446549),
#  ('fay', 1.1544927470625663),
#  ('tony', 1.1476543737357123),
#  ('contrast', 1.1468143904859875),
#  ('highly', 1.1456244706651642),
#  ('fabulous', 1.144074662744867),
#  ('ned', 1.1430640512389434),
#  ('smooth', 1.1407237740182365),
#  ('emma', 1.1386176232818088),
#  ('dramas', 1.1370785694959058),
#  ('sensitive', 1.1357912919098638),
#  ('inspiring', 1.1284652518177909),
#  ('stellar', 1.1249295969854831),
#  ('helps', 1.1134824511475612),
#  ('diana', 1.1118575154181303),
#  ('adorable', 1.1118575154181303),
#  ('hank', 1.1113513144455394),
#  ('blend', 1.1104467463151124),
#  ('carrie', 1.1100409844917325),
#  ('shy', 1.1093075777848576),
#  ('depression', 1.1089750757036563),
#  ('jimmy', 1.1083684636134743),
#  ('today', 1.1082741995798466),
#  ('rival', 1.1069110914828049),
#  ('awesome', 1.1013633220399996),
#  ('intense', 1.0986122886681098),
#  ('tragic', 1.0986122886681098),
#  ('achievement', 1.0986122886681098),
#  ('glorious', 1.0986122886681098),
#  ('unique', 1.0944106018144097),
#  ('provides', 1.0910076892828904),
#  ('bettie', 1.0904489780289488),
#  ('unexpected', 1.087973890463054),
#  ('ideal', 1.0857088838322018),
#  ('happiness', 1.0843263314206333),
#  ('terrifying', 1.0799201556559572),
#  ('fears', 1.0775588794702773),
#  ('davis', 1.065089596629466),
#  ('definite', 1.0647107369924282),
#  ('hong', 1.0640067594906342),
#  ('seasons', 1.0596101308648405),
#  ('carries', 1.0581209273133727),
#  ('beauty', 1.0563099089774204),
#  ('touched', 1.052092273033217),
#  ('fascinating', 1.0513061712711727),
#  ('satisfying', 1.0498221244986776),
#  ('enterprise', 1.0479685558493548),
#  ('aunt', 1.0453677741492975),
#  ('creates', 1.0396139479061539),
#  ('walter', 1.039423417277779),
#  ('spectacular', 1.0350988829457839),
#  ('musicals', 1.0311710078725771),
#  ('greatest', 1.0299837822790134),
#  ('triumph', 1.0296194171811581),
#  ('margaret', 1.0296194171811581),
#  ('mature', 1.0266387890430204),
#  ('portrayal', 1.0264159974636204),
#  ('ann', 1.0258529343856813),
#  ('deeply', 1.0211805485352936),
#  ('navy', 1.017923377417967),
#  ('joey', 1.0169342576538425),
#  ('lucas', 1.0163741904311376),
#  ('incredible', 1.012812298864777),
#  ('widow', 1.0116009116784799),
#  ('balance', 1.0094845087721023),
#  ('carrey', 1.0090001299784226),
#  ('brazil', 1.0086640520051702),
#  ('awe', 1.0082282271998408),
#  ('guilt', 1.0068047394149868),
#  ('glover', 1.0068047394149868),
#  ('essence', 1.0042026041970351),
#  ('sons', 1.0024684281152074),
#  ('sport', 1.0021520224805474),
#  ('warm', 1.0011139241832319),
#  ('harry', 0.99980136474732484),
#  ('ages', 0.9993140676858292),
#  ('destiny', 0.99852883011112725),
#  ('eerie', 0.99714282850325009),
#  ('sweet', 0.99613361938517231),
#  ('learns', 0.99507160972726938),
#  ('holmes', 0.99493385919326827),
#  ('oscar', 0.991501712902498),
#  ('unusual', 0.98971820042897229),
#  ('ginger', 0.98941299670311778),
#  ('lonely', 0.98815529310379902),
#  ('grim', 0.98815529310379902),
#  ('thrillers', 0.98690829908810851),
#  ('complex', 0.98620272107286944),
#  ('vhs', 0.98407074693589713),
#  ('solid', 0.98265240757324135),
#  ('cox', 0.98082925301172619),
#  ('comfortable', 0.98082925301172619),
#  ('debut', 0.97906713801832701),
#  ('hooked', 0.97753435711487369),
#  ('stanley', 0.97537964824416146),
#  ('beautiful', 0.9749394589556627),
#  ('rose', 0.97145711318286299),
#  ('tears', 0.97094914441201907),
#  ('winning', 0.96508089604358704),
#  ('feelings', 0.9646439285907088),
#  ('mysteries', 0.96343751029985703),
#  ('hal', 0.96343751029985703),
#  ('mgm', 0.96248011434352965),
#  ('perry', 0.96227584511597841),
#  ('paris', 0.96167373772197273),
#  ('lovable', 0.95551144502743635),
#  ('heart', 0.95509443084291101),
#  ('danny', 0.95048209662243432),
#  ('lifestyle', 0.95019228354983643),
#  ('themes', 0.94962715214174698),
#  ('anime', 0.9485989751068129),
#  ('masterpiece', 0.9473813189441862),
#  ('gradually', 0.94614369502383622),
#  ('joy', 0.94513888621181341),
#  ('louis', 0.94446160884085151),
#  ('kennedy', 0.94260804019152855),
#  ('urban', 0.94236297218393017),
#  ('subsequent', 0.93954759403842225),
#  ('italy', 0.93928025009885385),
#  ('allows', 0.93581715422451039),
#  ('charming', 0.93269676726126505),
#  ('winter', 0.93155820400494349),
#  ('spy', 0.92998957623231693),
#  ('highest', 0.92953595862417571),
#  ('secrets', 0.92871325187271225),
#  ('impact', 0.92754788639878949),
#  ('pleased', 0.92734056806074006),
#  ('norman', 0.92734056806074006),
#  ('raw', 0.9242589015233319),
#  ('reveals', 0.9239536046197242),
#  ('treat', 0.92286249703738954),
#  ('danes', 0.9223330463301177),
#  ('colorful', 0.92115692152532802),
#  ('surprising', 0.92093111143065731),
#  ('thief', 0.92072532894202075),
#  ('loving', 0.92072532894202075),
#  ('quiet', 0.91875682436934858),
#  ('bleak', 0.91629073187415511),
#  ('kudos', 0.91629073187415511),
#  ('todd', 0.91629073187415511),
#  ('funniest', 0.91044845624992665),
#  ('subtitles', 0.90532170050358107),
#  ('fonda', 0.90371194966729496),
#  ('compelling', 0.90359790507573612),
#  ('baseball', 0.90330353634734395),
#  ('season', 0.90274650676639789),
#  ('winner', 0.90125285450961445),
#  ('castle', 0.89982945482008303),
#  ('eastwood', 0.89608802455663572),
#  ('tragedy', 0.89511573473769646),
#  ('essential', 0.89478452665319141),
#  ('nicely', 0.89067815601742883),
#  ('intensity', 0.88985747480599964),
#  ('focuses', 0.88952049080955031),
#  ('great', 0.88848342517141643),
#  ('worlds', 0.88730319500090271),
#  ('health', 0.88583152438944646),
#  ('arthur', 0.88460122091717253),
#  ('gorgeous', 0.88238918019847368),
#  ('witty', 0.88066355423100395),
#  ('purple', 0.88035872264809167),
#  ('rob', 0.87771845708791529),
#  ('natural', 0.87730528516120132),
#  ('lucy', 0.87724021700228194),
#  ('deeper', 0.87707001872087376),
#  ('magical', 0.8769296579935747),
#  ('enjoyed', 0.8734230496306068),
#  ('craig', 0.87082835779739776),
#  ('modesty', 0.87082835779739776),
#  ('sings', 0.86977071623926216),
#  ('tear', 0.86113891179907498),
#  ('lovely', 0.86081157955392651),
#  ('moving', 0.85959538819760972),
#  ('disagree', 0.85822693091939395),
#  ('relate', 0.8574502318512216),
#  ('hart', 0.8564722366632449),
#  ('memorable', 0.85302443294440489),
#  ('dave', 0.8513711857748395),
#  ('princess', 0.84971624125148526),
#  ('forbidden', 0.84729786038720367),
#  ('jake', 0.84729786038720367),
#  ('smith', 0.84633214326724471),
#  ('episodes', 0.84577694754649702),
#  ('kung', 0.84533899590187067),
#  ('strong', 0.84469707868714616),
#  ('apartment', 0.84308732785086016),
#  ('columbo', 0.84267891453090915),
#  ('realizes', 0.84012937090859119),
#  ('manager', 0.8383291904044432),
#  ('adventure', 0.83797812843840136),
#  ('dancer', 0.83772840937105286),
#  ('strength', 0.83759846329849019),
#  ('tight', 0.83685390122612036),
#  ('explicit', 0.83532166934048779),
#  ('adds', 0.83461270085988781),
#  ('carl', 0.83422577881985094),
#  ('surreal', 0.83359901602904163),
#  ('miike', 0.83290912293510388),
#  ('childhood', 0.83129751904076243),
#  ('studios', 0.82894872171900713),
#  ('con', 0.82894872171900713),
#  ('dances', 0.8286926725561693),
#  ('abc', 0.82832195892819782),
#  ('kurt', 0.8280664984593159),
#  ('eyre', 0.82667857318446791),
#  ('waters', 0.82098055206983034),
#  ('develops', 0.82098055206983034),
#  ('sides', 0.82014687132125286),
#  ('touches', 0.81970990386837461),
#  ('importance', 0.81902742644894799),
#  ('oscars', 0.81831032351395128),
#  ('traditional', 0.81793795337373354),
#  ('deals', 0.81793795337373354),
#  ('empire', 0.8167611365271219),
#  ('holds', 0.81574950265227764),
#  ('albert', 0.81503699816898212),
#  ('gene', 0.81484411553746505),
#  ('backgrounds', 0.81450803756421286),
#  ('matches', 0.81450803756421286),
#  ('styles', 0.81409979097760776),
#  ('daring', 0.81409979097760776),
#  ('legendary', 0.81281168431603446),
#  ('realistic', 0.8123598090259232),
#  ('hearted', 0.80931861232198732),
#  ('sentimental', 0.80845802707093972),
#  ('cry', 0.80821651034473263),
#  ('portraying', 0.80775056329894912),
#  ('environment', 0.80680649903246682),
#  ('gothic', 0.80562516398663564),
#  ('tense', 0.80381274844746464),
#  ('achieved', 0.80314807577427383),
#  ('impressed', 0.80171356111140479),
#  ('captured', 0.79850769621777162),
#  ('jean', 0.79758984392754273),
#  ('edge', 0.79704677557809678),
#  ('sharp', 0.79694397424158891),
#  ('court', 0.79600456599965308),
#  ('covers', 0.79492987486988764),
#  ('reunion', 0.79424329743131417),
#  ('steals', 0.79395187968191083),
#  ('blob', 0.79323063911692793),
#  ('colors', 0.79284654078303329),
#  ('rules', 0.79223808320417632),
#  ('conventional', 0.79112758892014912),
#  ('denzel', 0.79052134458512169),
#  ('frank', 0.78972800856572589),
#  ('landscape', 0.78592891401091158),
#  ('stays', 0.78526246946775102),
#  ('rain', 0.78411895876567206),
#  ('immensely', 0.78275933924963248),
#  ('maria', 0.78015855754957497),
#  ('spring', 0.77908961036066993),
#  ('cagney', 0.77908961036066993),
#  ('midnight', 0.77866935399810722),
#  ('tale', 0.77411624309361238),
#  ('titanic', 0.77318988823348167),
#  ('sunday', 0.77318988823348167),
#  ('fresh', 0.76995259178369035),
#  ('sir', 0.76787072675588186),
#  ('nowadays', 0.76590653484237359),
#  ('influenced', 0.76409891653222972),
#  ('florida', 0.76409891653222972),
#  ('nevertheless', 0.76391625144815245),
#  ('animated', 0.76376474777389869),
#  ('leslie', 0.76335143923319382),
#  ('driven', 0.76301686052043127),
#  ('packed', 0.76080582903376015),
#  ('strikes', 0.76058846135547775),
#  ('secretary', 0.7591051483517427),
#  ('memories', 0.7583877024283463),
#  ('golden', 0.75730912477723111),
#  ('che', 0.75722603724446769),
#  ('provoking', 0.75709590516021885),
#  ('elderly', 0.75686299494605314),
#  ('enjoyable', 0.7561743371129005),
#  ('lovers', 0.75566753754127924),
#  ('depiction', 0.75484074956528524),
#  ('trek', 0.75233605195027597),
#  ('performances', 0.75054338956426092),
#  ('simple', 0.74945835212266076),
#  ('relationship', 0.74806293815605995),
#  ('bears', 0.74721440183022114),
#  ('supporting', 0.7470322690549247),
#  ('germany', 0.74649316126523801),
#  ('verhoeven', 0.74444047494749577),
#  ('bugs', 0.74290869011900906),
#  ('lewis', 0.74247224712244675),
#  ('emotional', 0.74148800749422783),
#  ('china', 0.74115639974630598),
#  ('anger', 0.74040006541049086),
#  ('portrays', 0.73936002371507692),
#  ('owner', 0.7391322938017687),
#  ('streets', 0.73809856842221155),
#  ('march', 0.73759894313077912),
#  ('endearing', 0.7366322924996842),
#  ('brings', 0.73631935242515412),
#  ('henry', 0.73396917508020054),
#  ('donald', 0.7326780193165805),
#  ('greatly', 0.73236789371322664),
#  ('available', 0.73206259680961894),
#  ('ken', 0.72996115368266168),
#  ('society', 0.7288652631620246),
#  ('sophisticated', 0.72823850037121551),
#  ('brad', 0.72763335663111472),
#  ('delivers', 0.72704873223562672),
#  ('effectively', 0.72540804277816673),
#  ('magic', 0.72530429219447679),
#  ('jim', 0.72410940616391217),
#  ('best', 0.72394778153021899),
#  ('andrew', 0.72391883922669897),
#  ('relationships', 0.72237681887488359),
#  ('influence', 0.72172055300400129),
#  ('simon', 0.72084978310928105),
#  ('affected', 0.7198154276421066),
#  ('beatty', 0.7198154276421066),
#  ('india', 0.71825310169102152),
#  ('emotionally', 0.71814848276536247),
#  ('charlie', 0.71716205676381928),
#  ('identity', 0.71667767797013937),
#  ('dan', 0.71613669878464414),
#  ('britain', 0.71334988787746478),
#  ('genius', 0.71308139546076266),
#  ('roy', 0.71294980785612505),
#  ('patient', 0.71219537553063972),
#  ('stylish', 0.71219537553063972),
#  ('atmosphere', 0.71157144788600379),
#  ('bitter', 0.71149631922814194),
#  ('wave', 0.71053892327181456),
#  ('directs', 0.70774597998109789),
#  ('rebel', 0.70774597998109789),
#  ('cowboy', 0.70733181555190172),
#  ('sky', 0.70719893401559564),
#  ('surprisingly', 0.70605058539585308),
#  ('wells', 0.70556970055850243),
#  ('dawson', 0.70470800296102132),
#  ('complaint', 0.70395809666416098),
#  ('refuses', 0.70290335550530991),
#  ('brooks', 0.70203612797719128),
#  ('match', 0.70073255194920192),
#  ('romantic', 0.70016475321859184),
#  ('patrick', 0.69988121274128945),
#  ('andy', 0.69785307159735799),
#  ('meets', 0.69758177762781104),
#  ('sunshine', 0.69314718055994529),
#  ('paul', 0.69314718055994529),
#  ('greater', 0.69314718055994529),
#  ('noble', 0.69314718055994529),
#  ('brando', 0.69314718055994529),
#  ('interpretation', 0.69314718055994529),
#  ('relations', 0.69314718055994529),
#  ('le', 0.69314718055994529),
#  ('sports', 0.69314718055994529),
#  ('handsome', 0.69314718055994529),
#  ('france', 0.69314718055994529),
#  ('luke', 0.69314718055994529),
#  ('love', 0.69244991150206125),
#  ('unlike', 0.69057978505469952),
#  ('award', 0.68956935921206131),
#  ('ride', 0.6895174125093666),
#  ('performance', 0.68900638789391389),
#  ('rings', 0.68504997032732595),
#  ('succeeds', 0.68417851057718493),
#  ('paced', 0.68309684470644383),
#  ('glimpse', 0.68309684470644383),
#  ('aired', 0.68289068039275624),
#  ('dreams', 0.68282006640409565),
#  ('imaginative', 0.6824518914431974),
#  ('tricks', 0.68221811002775501),
#  ('striking', 0.68221811002775501),
#  ('carefully', 0.68197387996182013),
#  ('effective', 0.68145114079675406),
#  ('h', 0.68131272291294254),
#  ('demands', 0.67990195380992458),
#  ('instant', 0.67875844310784572),
#  ('ruthless', 0.67833209477480472),
#  ('saga', 0.67833209477480472),
#  ('works', 0.67677254568815526),
#  ('master', 0.67667234335644022),
#  ('complicated', 0.67634006224356402),
#  ('lion', 0.67512867505726692),
#  ('england', 0.67353870917156899),
#  ('easy', 0.67264320036223801),
#  ('trilogy', 0.67238518911151623),
#  ('perspective', 0.67067432470788668),
#  ('city', 0.67067432470788668),
#  ('distant', 0.66904962898088483),
#  ('accomplished', 0.66904962898088483),
#  ('manhattan', 0.66845456796957381),
#  ('sees', 0.66811110239862037),
#  ('victor', 0.66782937257565544),
#  ('pushing', 0.66782937257565544),
#  ('appreciate', 0.66663605501161338),
#  ('workers', 0.66599619149399447),
#  ('eccentric', 0.66574820637183096),
#  ('divorce', 0.664976303593249),
#  ('colonel', 0.664976303593249),
#  ('douglas', 0.66470924523941177),
#  ('definitely', 0.66385836049190772),
#  ('both', 0.66334655288064115),
#  ('inspired', 0.66303737908857485),
#  ('future', 0.66160929704534466),
#  ('hudson', 0.66139848224536502),
#  ('joseph', 0.66099006892541401),
#  ('marriage', 0.6609440400653106),
#  ('page', 0.65872695667346604),
#  ('joan', 0.65857583649485663),
#  ('brave', 0.65624262362449437),
#  ('seeking', 0.65610590887959619),
#  ('progress', 0.65587578576271366),
#  ('meeting', 0.65540685257709819),
#  ('individual', 0.65540685257709819),
#  ('pleasant', 0.65492596773974754),
#  ('friendly', 0.65453234443216579),
#  ('era', 0.65430734724368145),
#  ('father', 0.65309967943066982),
#  ('fantasy', 0.651761964397091),
#  ('larger', 0.65147448415937725),
#  ('concert', 0.65147448415937725),
#  ('awards', 0.65058756614114943),
#  ('griffith', 0.64934455790155243),
#  ('personal', 0.64816918527686773),
#  ('ted', 0.64802674527947579),
#  ('albeit', 0.64574494166536145),
#  ('william', 0.6456975808469575),
#  ('nation', 0.6451379613735847),
#  ('adapted', 0.6448286032891376),
#  ('keeping', 0.64462013966528486),
#  ('emily', 0.64435701639051324),
#  ('jack', 0.64152281515463816),
#  ('recognized', 0.64050344707452334),
#  ('mouse', 0.64003735524599692),
#  ('profound', 0.63965849560895904),
#  ('jane', 0.63883519120620547),
#  ('discovers', 0.6374051975517101),
#  ('contract', 0.63598876671999671),
#  ('gives', 0.63566550827205481),
#  ('animation', 0.63557732873846751),
#  ('segment', 0.6346509738783368),
#  ('peoples', 0.63430668053701189),
#  ('sexuality', 0.63372376008914455),
#  ('morgan', 0.63350891424021416),
#  ('ultimate', 0.6332490389788763),
#  ('criticism', 0.63304325649023985),
#  ('drew', 0.63252255874351049),
#  ('families', 0.63101539945293916),
#  ('artist', 0.63034627932091492),
#  ('determined', 0.62977756662735607),
#  ('versions', 0.62860865942237409),
#  ('fashioned', 0.62860865942237409),
#  ('moved', 0.62860865942237409),
#  ('tap', 0.62860865942237409),
#  ('impressive', 0.62784208215217863),
#  ('charismatic', 0.62718921276814787),
#  ('trio', 0.62689779501874465),
#  ('classic', 0.62661819205313174),
#  ('eddie', 0.62613647027698516),
#  ('innocent', 0.6253850784591265),
#  ('shine', 0.62509371731492969),
#  ('brady', 0.62509371731492969),
#  ('remembered', 0.62415430907299385),
#  ('satisfied', 0.623188591953035),
#  ('melodrama', 0.62252961334599188),
#  ('ward', 0.62252961334599188),
#  ('washington', 0.62227284097328828),
#  ('brian', 0.62153764818182222),
#  ('rough', 0.62140327570110399),
#  ('pleasure', 0.62117368093485603),
#  ('offers', 0.62030985660767901),
#  ('nature', 0.61996929683166635),
#  ('games', 0.61903920840622351),
#  ('academy', 0.61829928976351289),
#  ('images', 0.61763962805180017),
#  ('dealing', 0.61576051694452505),
#  ('figures', 0.61558894621407079),
#  ('russell', 0.61481533729003834),
#  ('bound', 0.61045546471483192),
#  ('cook', 0.60937729749448644),
#  ('morality', 0.608247736773459),
#  ('falk', 0.608247736773459),
#  ('claire', 0.60762500712178336),
#  ('fine', 0.60710866092888249),
#  ('hall', 0.60613580357031549),
#  ('river', 0.60613580357031549),
#  ('brown', 0.60613580357031549),
#  ('stood', 0.60419969454344913),
#  ('kubrick', 0.60217540235421851),
#  ('broadway', 0.60189850909480025),
#  ('peace', 0.59988968707336265),
#  ('job', 0.59969401150283319),
#  ('believable', 0.59962112254912181),
#  ('clint', 0.59911823091166894),
#  ('anna', 0.59895996550024422),
#  ('expressions', 0.59783700075562041),
#  ('struggles', 0.59783700075562041),
#  ('experiences', 0.59713252732035671),
#  ('timing', 0.59700332000704304),
#  ('visually', 0.59620523536771486),
#  ('helen', 0.59598343210629756),
#  ('always', 0.59557554028064663),
#  ('authentic', 0.59529139055618674),
#  ('growing', 0.59405627791571447),
#  ('streep', 0.5937747067467416),
#  ('timothy', 0.59306372200296276),
#  ('quirky', 0.59136448625000293),
#  ('personalities', 0.58976882610611026),
#  ('mexico', 0.58946875108510377),
#  ('inner', 0.58778666490211906),
#  ('overcome', 0.58778666490211906),
#  ('civil', 0.58778666490211906),
#  ('australia', 0.58778666490211906),
#  ('touch', 0.58712898648314826),
#  ('sisters', 0.58628403501758408),
#  ('tales', 0.58590165020634777),
#  ('pre', 0.58581816032944667),
#  ('countries', 0.58572693193910841),
#  ('wealth', 0.58493359591971261),
#  ('overwhelming', 0.58493359591971261),
#  ('odds', 0.58493359591971261),
#  ('surprises', 0.58473788205276045),
#  ('adventures', 0.58473788205276045),
#  ('tradition', 0.58394788859495339),
#  ('lives', 0.58309967942199548),
#  ('realism', 0.58221561985266368),
#  ('survival', 0.58192154544972097),
#  ('performing', 0.58066919713325493),
#  ('rogers', 0.58047401805583243),
#  ('oliver', 0.57931203791114672),
#  ('suspenseful', 0.57807785077515805),
#  ('variety', 0.57807785077515805),
#  ('kirk', 0.57688737444408333),
#  ('young', 0.57607573676451462),
#  ('french', 0.57558419111415371),
#  ('understanding', 0.5753641449035618),
#  ('reminiscent', 0.5753641449035618),
#  ('players', 0.57475716461178528),
#  ('branagh', 0.57443087372056334),
#  ('psychological', 0.57145024558242552),
#  ('jr', 0.57134230667574193),
#  ('knowing', 0.57108481528418742),
#  ('war', 0.56978179089911041),
#  ('disc', 0.56953322459276867),
#  ('bug', 0.56953322459276867),
#  ('mainstream', 0.56935296321328099),
#  ('howard', 0.56869300608653939),
#  ('grand', 0.56858445791818302),
#  ('grow', 0.5683954755874685),
#  ('generation', 0.5679840376059393),
#  ('sent', 0.56658445725151607),
#  ('sacrifice', 0.56580775818334383),
#  ('tribute', 0.56531380905006046),
#  ('sutherland', 0.56452980273785169),
#  ('true', 0.56399658685393184),
#  ('brothers', 0.563850092074211),
#  ('dick', 0.563613128368043),
#  ('describes', 0.56346935725141267),
#  ('tend', 0.56327209913853316),
#  ('greek', 0.56309405231174747),
#  ('hamilton', 0.56309405231174747),
#  ('gangster', 0.56265069163057668),
#  ('hearts', 0.5625269981428811),
#  ('jeff', 0.5609255458174861),
#  ('david', 0.55961578793542266),
#  ('charm', 0.55961578793542266),
#  ('documentaries', 0.55961578793542266),
#  ('redemption', 0.55961578793542266),
#  ('jealous', 0.55961578793542266),
#  ('mountains', 0.55961578793542266),
#  ('twists', 0.55871691147040559),
#  ('europe', 0.55780583269018313),
#  ('pulls', 0.55748131540679002),
#  ('madness', 0.55719154432391638),
#  ('trial', 0.55701500623536526),
#  ('brilliance', 0.55657164555419458),
#  ('thanks', 0.55628799784274796),
#  ('providing', 0.55628799784274796),
#  ('explore', 0.55628799784274796),
#  ('olivier', 0.55594605904646033),
#  ('roman', 0.55594605904646033),
#  ('shorts', 0.55431073570572953),
#  ('dealt', 0.55388511322643763),
#  ('faithful', 0.55300054881670346),
#  ('heroic', 0.55278982286502287),
#  ('superior', 0.55206858230003986),
#  ('family', 0.55201678090657069),
#  ('color', 0.55083095837968976),
#  ('jackson', 0.55035646252262593),
#  ('ironically', 0.55004633691927196),
#  ('temple', 0.55004633691927196),
#  ('world', 0.54815434441641608),
#  ('received', 0.547639596888707),
#  ('gift', 0.547639596888707),
#  ('life', 0.54736675168202076),
#  ('york', 0.54654370636806993),
#  ('stands', 0.54582246580308691),
#  ('jazz', 0.54522705048332309),
#  ('revolution', 0.54501698851427005),
#  ('union', 0.54430155296238014),
#  ('enjoy', 0.54274322673429576),
#  ('julie', 0.54159728243274441),
#  ('share', 0.54146259322788048),
#  ('pays', 0.54113097326131954),
#  ('each', 0.53987330920622145),
#  ('fellow', 0.53960458831603408),
#  ('symbolism', 0.5389965007326869),
#  ('different', 0.53823691087466852),
#  ('loves', 0.53731723921296703),
#  ('countryside', 0.53680111016925136),
#  ('ourselves', 0.53596159703753288),
#  ('approach', 0.53534018952957652),
#  ('century', 0.535142931416697),
#  ('dennis', 0.535142931416697),
#  ('aging', 0.53492317534505118),
#  ('wwii', 0.53467683958817058),
#  ('appearances', 0.53408248593025787),
#  ('jeremy', 0.53408248593025787),
#  ('radio', 0.53342545568323163),
#  ('series', 0.53337237501387191),
#  ('performed', 0.53311066855542566),
#  ('demons', 0.53311066855542566),
#  ('moves', 0.53302633374618325),
#  ('musical', 0.53238980168183114),
#  ('uncle', 0.53157656787102969),
#  ('reminds', 0.53062825106217038),
#  ('arrives', 0.53062825106217038),
#  ('lust', 0.53062825106217038),
#  ('discovered', 0.52884412926866897),
#  ('eric', 0.52884412926866897),
#  ('carter', 0.52852520086539156),
#  ('youth', 0.52831878121350784),
#  ('horrors', 0.52806743020049673),
#  ('epic', 0.52763274208237188),
#  ('tarzan', 0.52735492571720122),
#  ('deep', 0.527219433541667),
#  ('tells', 0.52720451585003036),
#  ('sympathetic', 0.52716204308568415),
#  ('attitude', 0.52660949146725267),
#  ('com', 0.52553177115568617),
#  ('karloff', 0.52526630792078499),
#  ('passion', 0.52526630792078499),
#  ('atmospheric', 0.52526630792078499),
#  ('desire', 0.52488560933428929),
#  ('famous', 0.52466667517786214),
#  ('adult', 0.52441705096952973),
#  ('duo', 0.52407085051601132),
#  ('cameron', 0.52407085051601132),
#  ('daily', 0.52385512405632462),
#  ('provided', 0.52372902860189852),
#  ('dirty', 0.52354439617376536),
#  ('fox', 0.52354439617376536),
#  ('investigation', 0.52324814376454787),
#  ('shining', 0.52324814376454787),
#  ('fits', 0.52324814376454787),
#  ('proud', 0.52218938241630575),
#  ('smile', 0.52187545995257567),
#  ('traveling', 0.52129692363328606),
#  ('visit', 0.52097799523000865),
#  ('shows', 0.52031533738393043),
#  ('human', 0.52019337376959085),
#  ('south', 0.51987545928590861),
#  ('ring', 0.5194093674573822),
#  ('individuals', 0.51930025075696296),
#  ('hitchcock', 0.51848849651155982),
#  ('alan', 0.5184302231512099),
#  ('accurate', 0.51834445618001801),
#  ('japan', 0.51813827061227724),
#  ('present', 0.51775806054163553),
#  ('fu', 0.51652364488062841),
#  ('possibility', 0.51581316527702981),
#  ('differences', 0.51546600332249293),
#  ('fun', 0.51538324584323847),
#  ('stunts', 0.51466440007315639),
#  ('finding', 0.51380625190412843),
#  ('position', 0.51380625190412843),
#  ('success', 0.51356160358486547),
#  ('frightening', 0.51356160358486547),
#  ('begins', 0.51350659051924841),
#  ('contemporary', 0.51335407011934941),
#  ('recently', 0.51174685828531152),
#  ('desperation', 0.51082562376599072),
#  ('companion', 0.51082562376599072),
#  ('genuine', 0.51082562376599072),
#  ('hugh', 0.51082562376599072),
#  ('battles', 0.51082562376599072),
#  ('league', 0.51082562376599072),
#  ('helping', 0.51082562376599072),
#  ('answers', 0.51082562376599072),
#  ('continues', 0.50878272213619036),
#  ('appropriate', 0.50841307736060681),
#  ('honor', 0.50774395722858268),
#  ('tracy', 0.5075946031845443),
#  ('among', 0.50673563851446557),
#  ('guide', 0.50656122497953315),
#  ('viewing', 0.50656122497953315),
#  ('intrigue', 0.5059356384717989),
#  ('warming', 0.5059356384717989),
#  ('cuba', 0.5059356384717989),
#  ('depicted', 0.50574947073413001),
#  ('planned', 0.50554856666514691),
#  ('brutal', 0.50554856666514691),
#  ('initially', 0.50483758192136796),
#  ('finds', 0.50408023562645909),
#  ('combination', 0.5039051809214169),
#  ('age', 0.50178009672451207),
#  ('thoroughly', 0.50169314020271816),
#  ('broadcast', 0.50147976134775307),
#  ('brought', 0.50142909636990807),
#  ('plays', 0.50095672672274849),
#  ('james', 0.5008504787091711),
#  ('official', 0.50077528791248915),
#  ('roles', 0.50077528791248915),
#  ('primary', 0.50077528791248915),
#  ('hilarious', 0.49986660997627119),
#  ('julia', 0.49949405775644073),
#  ('san', 0.49949405775644073),
#  ('dance', 0.49937238475248824),
#  ('fully', 0.49832546100175928),
#  ('nonetheless', 0.49783842823917956),
#  ('shakespeare', 0.49643688631389105),
#  ('strongly', 0.49643688631389105),
#  ('trade', 0.49561620510246196),
#  ('singing', 0.49444859448466799),
#  ('nine', 0.49429632181478017),
#  ('romance', 0.49395405792598318),
#  ('detail', 0.49375771525384266),
#  ('cup', 0.4936578201436253),
#  ('piano', 0.4936578201436253),
#  ('crime', 0.49325047894448321),
#  ('happy', 0.49262826471408305),
#  ('discovery', 0.49247648509779424),
#  ('settings', 0.49247648509779424),
#  ('vicious', 0.49247648509779424),
#  ('humanity', 0.49195713946160791),
#  ('necessary', 0.49112055268665822),
#  ('mistaken', 0.49112055268665822),
#  ('grey', 0.49062291644847122),
#  ('especially', 0.49005056119102625),
#  ('hatred', 0.48884671704721538),
#  ('sinister', 0.48798613179616795),
#  ('bird', 0.48729512635579658),
#  ('machines', 0.48729512635579658),
#  ('ordinary', 0.48701497507227215),
#  ('reveal', 0.48550781578170082),
#  ('smaller', 0.48550781578170082),
#  ('photographed', 0.48550781578170082),
#  ('pictures', 0.48506307483596678),
#  ('drama', 0.48407699567781781),
#  ('soviet', 0.48379695137807138),
#  ('max', 0.4836298809575007),
#  ('crisis', 0.48285177172358451),
#  ('inevitable', 0.48242614924429278),
#  ('losing', 0.48183808689273838),
#  ('challenge', 0.48183808689273838),
#  ('dated', 0.48097266061630956),
#  ('francisco', 0.4805857385762724),
#  ('techniques', 0.47957308026188628),
#  ('spirit', 0.47957308026188628),
#  ('surfing', 0.47957308026188628),
#  ('history', 0.4792923785056572),
#  ('genuinely', 0.47907692545141034),
#  ('familiar', 0.47725880012690741),
#  ('episode', 0.4768697670589348),
#  ('ways', 0.47647614375135305),
#  ('spielberg', 0.47633944769482134),
#  ('cynical', 0.47633944769482134),
#  ('tour', 0.47633944769482134),
#  ('defeat', 0.47608267532211779),
#  ('role', 0.4760206786575184),
#  ('ryan', 0.47290638890369696),
#  ('higher', 0.47225334897975102),
#  ('warner', 0.47184017705303705),
#  ('african', 0.47127832667773606),
#  ('born', 0.47084786737101608),
#  ('critics', 0.47082028915229157),
#  ('dream', 0.47000362924573563),
#  ('shadows', 0.47000362924573563),
#  ('detective', 0.4692971650694085),
#  ('deserved', 0.46888693454566049),
#  ('lynch', 0.46883472204075372),
#  ('remains', 0.46852324407530127),
#  ('information', 0.46806376442790892),
#  ('breaking', 0.46719068786912082),
#  ('struggle', 0.46702300110759781),
#  ('closely', 0.46536324968923332),
#  ('segments', 0.46536324968923332),
#  ('hidden', 0.46430560813109778),
#  ('web', 0.46430560813109778),
#  ('language', 0.46388740222829949),
#  ('treasure', 0.46357273891544509),
#  ('oz', 0.46357273891544509),
#  ('hamlet', 0.46328467899699055),
#  ('visual', 0.46317342572881115),
#  ('represents', 0.46262352194811296),
#  ('presents', 0.4621604517847096),
#  ('restaurant', 0.4618180446592961),
#  ('social', 0.46163537957521894),
#  ('mixed', 0.46095379372581763),
#  ('chief', 0.46012352064602852),
#  ('reality', 0.45980784942426633),
#  ('rap', 0.45953232937844013),
#  ('caine', 0.45886588483527962),
#  ('popular', 0.45879076464293661),
#  ('modern', 0.4577764026761752),
#  ('sometimes', 0.45774661461820548),
#  ('follows', 0.45762158770252609),
#  ('justice', 0.45758110924717832),
#  ('searching', 0.45675840249571492),
#  ('birth', 0.45675840249571492),
#  ('surprised', 0.45665121561528643),
#  ('welcome', 0.45635671540455369),
#  ('keeps', 0.45635671540455369),
#  ('wallace', 0.45601738727099561),
#  ('controversial', 0.45506204924753652),
#  ('jon', 0.45447268721485901),
#  ('closer', 0.45425527227759638),
#  ('ocean', 0.45425527227759638),
#  ('enormous', 0.45425527227759638),
#  ('revolutionary', 0.45425527227759638),
#  ('lose', 0.45401833352515514),
#  ('thrilling', 0.45347432729452497),
#  ('bridge', 0.45347432729452497),
#  ('elizabeth', 0.45332112928579943),
#  ('john', 0.45325577194451278),
#  ('fame', 0.4530060528771645),
#  ('chinese', 0.45267884558842952),
#  ('visuals', 0.45198512374305722),
#  ('cary', 0.45198512374305722),
#  ('caught', 0.45072169969628523),
#  ('marry', 0.44991687067899816),
#  ('years', 0.44976031361568897),
#  ('puts', 0.44952509790219486),
#  ('nazi', 0.44952509790219486),
#  ('michelle', 0.44926773076655735),
#  ('criminal', 0.44911773826590118),
#  ('learned', 0.44830526678465676),
#  ('wayne', 0.44802472252696035),
#  ('glenn', 0.44802472252696035),
#  ('minor', 0.44731221804366483),
#  ('flaws', 0.44685032427101867),
#  ('comedic', 0.4453110166553641),
#  ('chaos', 0.4453110166553641),
#  ('travels', 0.4453110166553641),
#  ('maggie', 0.4453110166553641),
#  ('beings', 0.44468582126144574),
#  ('pride', 0.44425113314332088),
#  ('slowly', 0.44404857414732085),
#  ('sandler', 0.44393138893596046),
#  ('physical', 0.44361687407254063),
#  ('de', 0.44333538216357421),
#  ('international', 0.44320543609101143),
#  ('stronger', 0.44320543609101143),
#  ('shall', 0.44320543609101143),
#  ('flawed', 0.44300302742722958),
#  ('johnny', 0.44300302742722958),
#  ...]

# %%
list(reversed(PN_ratios.most_common()))
# Out:
# [('unfunny', -2.6882475738060303),
#  ('waste', -2.6186484579840514),
#  ('pointless', -2.4531579514734201),
#  ('redeeming', -2.3648889763302003),
#  ('lousy', -2.3025850929940455),
#  ('worst', -2.2865847516476046),
#  ('laughable', -2.2617630984737906),
#  ('awful', -2.2265521924307397),
#  ('poorly', -2.2192034840549946),
#  ('sucks', -1.9830278120118159),
#  ('lame', -1.9802348915963879),
#  ('insult', -1.9730120788331045),
#  ('horrible', -1.9093035277056216),
#  ('amateurish', -1.9042374526547454),
#  ('pathetic', -1.8979393212692839),
#  ('wasted', -1.836211231798889),
#  ('crap', -1.8270104186988547),
#  ('tedious', -1.7971214123694403),
#  ('dreadful', -1.7676619176489945),
#  ('badly', -1.751858252475869),
#  ('worse', -1.7364709637732161),
#  ('terrible', -1.7283898552954657),
#  ('embarrassing', -1.6969253665572162),
#  ('mess', -1.6882490928583902),
#  ('garbage', -1.6843392206072181),
#  ('pile', -1.6625477377480489),
#  ('stupid', -1.65455834771457),
#  ('vampires', -1.6143041020852733),
#  ('dull', -1.5831973397815833),
#  ('avoid', -1.5742391754682075),
#  ('wooden', -1.5664205273504095),
#  ('forgettable', -1.5463797764669633),
#  ('crappy', -1.5321047090309301),
#  ('whatsoever', -1.5079014932146775),
#  ('ridiculous', -1.5072469715375532),
#  ('excuse', -1.5069971068796089),
#  ('rubbish', -1.5040773967762742),
#  ('boring', -1.4903026115277032),
#  ('costs', -1.4350845252893227),
#  ('dumb', -1.4216778650092072),
#  ('bother', -1.4213856809311607),
#  ('horribly', -1.4098248585300848),
#  ('bland', -1.38173854458403),
#  ('annoying', -1.3651361356125447),
#  ('amateur', -1.3574739225843988),
#  ('bad', -1.3560837995970472),
#  ('unless', -1.3496602279401102),
#  ('fails', -1.34755353280346),
#  ('mediocre', -1.3391475826941885),
#  ('clich', -1.3217558399823195),
#  ('zombies', -1.3083328196501787),
#  ('disappointment', -1.3077040865266691),
#  ('asleep', -1.2953225829141639),
#  ('irritating', -1.2864740258376797),
#  ('disappointing', -1.2851982442485219),
#  ('utter', -1.2851982442485219),
#  ('supposed', -1.2792489250971448),
#  ('screaming', -1.2790488307662931),
#  ('poor', -1.2697875540065355),
#  ('unbelievable', -1.2616519159126141),
#  ('fake', -1.2568362938830038),
#  ('joke', -1.2404424841073274),
#  ('random', -1.2367626271489267),
#  ('cheap', -1.2348349157085943),
#  ('pretentious', -1.1847414423980485),
#  ('sucked', -1.179957928122062),
#  ('werewolf', -1.158331523369732),
#  ('painfully', -1.143563676530376),
#  ('offensive', -1.1433481825095013),
#  ('disgusting', -1.1290097658524807),
#  ('blame', -1.1263918527751855),
#  ('seconds', -1.1216018068928084),
#  ('trash', -1.1092224677801252),
#  ('ugly', -1.0910934562540824),
#  ('oh', -1.0885158284171002),
#  ('explanation', -1.0712133144799951),
#  ('failed', -1.063040822883242),
#  ('bored', -1.0538286860411363),
#  ('clue', -1.0515447778101239),
#  ('cgi', -1.0498221244986778),
#  ('sat', -1.0491640132541284),
#  ('paid', -1.0471303328329664),
#  ('painful', -1.0387519007444308),
#  ('nowhere', -1.0247234465689516),
#  ('predictable', -1.0220051671959129),
#  ('absurd', -1.0216512475319814),
#  ('porn', -1.0200004010984562),
#  ('paper', -1.0176432261344426),
#  ('sorry', -1.0089495623568598),
#  ('brain', -1.0080153933158831),
#  ('vampire', -1.0027119642612339),
#  ('unrealistic', -0.99507160972726938),
#  ('save', -0.99070809401642224),
#  ('santa', -0.98581679452276527),
#  ('contrived', -0.97881108885548906),
#  ('lacks', -0.97455963999813078),
#  ('gore', -0.97337144261759623),
#  ('bunch', -0.97295076543964643),
#  ('flat', -0.9665772303045248),
#  ('below', -0.96257148443816132),
#  ('plain', -0.9623474091479266),
#  ('honestly', -0.94882652192555239),
#  ('minutes', -0.94419286387820189),
#  ('lesbian', -0.92998957623231693),
#  ('chick', -0.92833907039032959),
#  ('f', -0.92798677163734644),
#  ('shallow', -0.916290731874155),
#  ('yeah', -0.90570862254361817),
#  ('nonsense', -0.89927938604761848),
#  ('unnecessary', -0.89585869305694921),
#  ('ruined', -0.8917496229580375),
#  ('somebody', -0.89067815601742872),
#  ('terribly', -0.88583152438944657),
#  ('hoping', -0.8838369870244166),
#  ('continuity', -0.88350090905116418),
#  ('nudity', -0.88258620512276398),
#  ('endless', -0.87788128375928387),
#  ('decent', -0.8683773761782575),
#  ('ok', -0.86325314958577593),
#  ('torture', -0.86322176374392656),
#  ('rented', -0.86288995514703981),
#  ('disaster', -0.86222351060387925),
#  ('fat', -0.85597094164063237),
#  ('rip', -0.85023903897801989),
#  ('attempt', -0.84729786038720367),
#  ('weak', -0.84479942061160485),
#  ('jesus', -0.83739678940449214),
#  ('apparently', -0.8338470626630804),
#  ('barely', -0.83350453825486781),
#  ('christian', -0.83329381230318711),
#  ('nothing', -0.832909122935104),
#  ('clichs', -0.82806649845931612),
#  ('explained', -0.82235891203995148),
#  ('couldn', -0.8184390319252236),
#  ('money', -0.81782204225425004),
#  ('total', -0.80693363653184336),
#  ('sake', -0.80506509676393068),
#  ('supposedly', -0.80204126879908266),
#  ('priest', -0.80136076520017807),
#  ('zombie', -0.79633141679517605),
#  ('unfortunately', -0.79125396324105524),
#  ('bottom', -0.79052134458512169),
#  ('bomb', -0.78968510760259258),
#  ('grade', -0.78592891401091147),
#  ('script', -0.7765707173411861),
#  ('okay', -0.77421500364872708),
#  ('producers', -0.77368604304395761),
#  ('monster', -0.77207443914961604),
#  ('confusing', -0.77186274802541932),
#  ('seriously', -0.76905614374526976),
#  ('premise', -0.7591988734560805),
#  ('promising', -0.7591051483517427),
#  ('k', -0.75566753754127924),
#  ('substance', -0.75545106389610017),
#  ('write', -0.7496593908232877),
#  ('rental', -0.74262723782331497),
#  ('guess', -0.7415995639458921),
#  ('zero', -0.74040006541049086),
#  ('scientist', -0.73799774672529705),
#  ('semi', -0.73631935242515412),
#  ('slasher', -0.73623076669625698),
#  ('silly', -0.73563445439926156),
#  ('logic', -0.73544956025063468),
#  ('throw', -0.7345843704241185),
#  ('alien', -0.73363854191468214),
#  ('instead', -0.73036719009617135),
#  ('accents', -0.73032618380169934),
#  ('skip', -0.72789012900381833),
#  ('effort', -0.72169336246630678),
#  ('par', -0.7198154276421066),
#  ('hated', -0.71859384622110956),
#  ('shoot', -0.71606144008282113),
#  ('fill', -0.71269177663291561),
#  ('gratuitous', -0.71219537553063983),
#  ('none', -0.70774597998109789),
#  ('stick', -0.70277807362090661),
#  ('rent', -0.7014805621190896),
#  ('assume', -0.69970458110610434),
#  ('weren', -0.69926340757738137),
#  ('failure', -0.6992262266363275),
#  ('thin', -0.69314718055994529),
#  ('stock', -0.69314718055994529),
#  ('tried', -0.69120731574211869),
#  ('suppose', -0.68559997492456237),
#  ('advice', -0.68158635815886925),
#  ('gonna', -0.68072466056138825),
#  ('mean', -0.67980772086601771),
#  ('looked', -0.67833209477480461),
#  ('channel', -0.67622630307160814),
#  ('spent', -0.66811110239862048),
#  ('low', -0.66740893952342495),
#  ('lacking', -0.66619137057141697),
#  ('hour', -0.66547245840372482),
#  ('reason', -0.66486766108132722),
#  ('lack', -0.66211507131221681),
#  ('saved', -0.66071190480679132),
#  ('makers', -0.65965851080590143),
#  ('makeup', -0.6567795363890705),
#  ('empty', -0.6552022489958218),
#  ('holes', -0.65232518603969014),
#  ('wouldn', -0.65215204085702239),
#  ('saying', -0.64750589960374128),
#  ('utterly', -0.64723747925586739),
#  ('cover', -0.64504738576553389),
#  ('please', -0.64199966939300435),
#  ('deserve', -0.64132211269535933),
#  ('mistake', -0.64077919504262937),
#  ('watchable', -0.63986581394700848),
#  ('neither', -0.63503954975266452),
#  ('whoever', -0.63430668053701189),
#  ('monsters', -0.63414883979798953),
#  ('creature', -0.62747807705208802),
#  ('flesh', -0.62705706873095524),
#  ('sequels', -0.62689779501874465),
#  ('why', -0.62425056936088641),
#  ('thats', -0.62252961334599188),
#  ('propaganda', -0.62012204554505546),
#  ('remake', -0.61941621123820989),
#  ('asian', -0.61811199461703126),
#  ('fail', -0.61518563909023338),
#  ('except', -0.61320942119946109),
#  ('flick', -0.6131044728864089),
#  ('favor', -0.61025952075417766),
#  ('dialog', -0.60848125614495208),
#  ('guy', -0.60639041846666242),
#  ('freddy', -0.6061358035703156),
#  ('problem', -0.60542532396671689),
#  ('least', -0.60150540005979225),
#  ('mouth', -0.59529139055618685),
#  ('hell', -0.59356966686576651),
#  ('wasn', -0.58832589381785405),
#  ('idea', -0.58489450975425594),
#  ('budget', -0.58473788205276034),
#  ('naked', -0.57854379782094156),
#  ('half', -0.57710565548178483),
#  ('cheesy', -0.57700753064729193),
#  ('no', -0.57677056688440498),
#  ('category', -0.57454143815209835),
#  ('stereotypes', -0.56760943561616828),
#  ('sequel', -0.56730813355857834),
#  ('somewhere', -0.56531380905006035),
#  ('weekend', -0.56531380905006035),
#  ('someone', -0.56483070428745041),
#  ('frankly', -0.56115070765350639),
#  ('editing', -0.55860210310457648),
#  ('walk', -0.5580785086165363),
#  ('cash', -0.55628799784274796),
#  ('cant', -0.55612538299565417),
#  ('anything', -0.55575452223660426),
#  ('dimensional', -0.55499684207912814),
#  ('research', -0.55431073570572942),
#  ('positive', -0.55431073570572942),
#  ('scare', -0.55244729845681018),
#  ('either', -0.5493140044075967),
#  ('sit', -0.54856595174883782),
#  ('wrong', -0.54756744941924806),
#  ('god', -0.54630606378140012),
#  ('looks', -0.5461273247185362),
#  ('thing', -0.54489563297272359),
#  ('sadly', -0.54254470078878425),
#  ('writers', -0.54070269462893583),
#  ('basically', -0.53799799840309737),
#  ('victims', -0.53779674054078286),
#  ('sleep', -0.5355182363563622),
#  ('plot', -0.53535776134999991),
#  ('dry', -0.53408248593025798),
#  ('saving', -0.53408248593025798),
#  ('killing', -0.53085711020037041),
#  ('deaths', -0.529079064075341),
#  ('tired', -0.52770366155334236),
#  ('seemed', -0.52690124931031423),
#  ('walking', -0.5266506649103877),
#  ('whatever', -0.52542442318714333),
#  ('killer', -0.52441129260766861),
#  ('wonder', -0.52420719246182201),
#  ('obviously', -0.52230680613994707),
#  ('computer', -0.52218938241630586),
#  ('review', -0.52149406508291418),
#  ('potential', -0.52129692363328606),
#  ('wood', -0.52067792020900228),
#  ('asking', -0.52019337376959085),
#  ('warning', -0.5194093674573822),
#  ('accent', -0.51853067014039589),
#  ('superman', -0.51775806054163542),
#  ('scary', -0.5173086286440689),
#  ('jokes', -0.51519960558910372),
#  ('imdb', -0.51387440661534922),
#  ('promise', -0.51326167856387173),
#  ('hey', -0.51212348248159067),
#  ('acting', -0.50942949164581275),
#  ('wow', -0.50096117879507684),
#  ('damn', -0.49740260343385001),
#  ('lower', -0.49589997354931498),
#  ('sex', -0.49439036128007829),
#  ('disappointed', -0.49167795435185652),
#  ('tries', -0.48994803874443538),
#  ('gay', -0.48982747692621725),
#  ('giant', -0.48977221456815834),
#  ('obvious', -0.48588667541873864),
#  ('complete', -0.48511726705578379),
#  ('thrown', -0.4835334814779832),
#  ('completely', -0.48240902610322328),
#  ('eat', -0.48183808689273833),
#  ('dubbed', -0.48012663687718399),
#  ('sub', -0.47789494595297893),
#  ('blood', -0.47768331591996355),
#  ('heck', -0.4773296693378084),
#  ('kills', -0.47675419185546603),
#  ('virtually', -0.47608267532211773),
#  ('sign', -0.47593836476555018),
#  ('call', -0.47458352099255657),
#  ('explain', -0.4743295191928581),
#  ('sitting', -0.4743295191928581),
#  ('flicks', -0.47364662052423667),
#  ('island', -0.47121648567094482),
#  ('wondering', -0.4709090163605481),
#  ('gory', -0.47000362924573558),
#  ('project', -0.46868000231522727),
#  ('filmmakers', -0.46770741698538537),
#  ('phone', -0.46292216313295165),
#  ('wearing', -0.46203545959655867),
#  ('hardly', -0.46152900225476329),
#  ('exist', -0.46134556650262093),
#  ('didn', -0.45902855103025414),
#  ('minute', -0.45643155170019195),
#  ('destroy', -0.45518854346059484),
#  ('effects', -0.45410691533051017),
#  ('guns', -0.45281122870536267),
#  ('rape', -0.4513447138588581),
#  ('dialogue', -0.45107561936021673),
#  ('thinking', -0.45020100194955592),
#  ('ass', -0.44935930166538968),
#  ('purpose', -0.4493234240081968),
#  ('spoiler', -0.44628710262841947),
#  ('pass', -0.44531101665536404),
#  ('aren', -0.44513036450059584),
#  ('cut', -0.44183275227903918),
#  ('any', -0.43930743825087909),
#  ('hopes', -0.43915895389463705),
#  ('otherwise', -0.43911314222639708),
#  ('even', -0.43731872302463409),
#  ('development', -0.43671765161226878),
#  ('possibly', -0.43257342686624251),
#  ('don', -0.4308982496950271),
#  ('care', -0.42959173072230106),
#  ('spoilers', -0.42572629324798633),
#  ('hanging', -0.42488319396526597),
#  ('scream', -0.42415724112031689),
#  ('spend', -0.42354283952812144),
#  ('qualities', -0.42159449003804794),
#  ('value', -0.42136369417596259),
#  ('soap', -0.42010665810111253),
#  ('teen', -0.41773520069997866),
#  ('practically', -0.41616039722491244),
#  ('video', -0.41606761706742884),
#  ('attempts', -0.41404885179955592),
#  ('nobody', -0.41284521540578695),
#  ('sick', -0.41231444995373923),
#  ('trying', -0.40917318584422291),
#  ('college', -0.40882645581086913),
#  ('killed', -0.406965483483399),
#  ('credits', -0.40670349835931091),
#  ('m', -0.40646560844174784),
#  ('heads', -0.40546510810816444),
#  ('blonde', -0.40546510810816444),
#  ('stopped', -0.40546510810816444),
#  ('lake', -0.40546510810816444),
#  ('claims', -0.40546510810816444),
#  ('pay', -0.40546510810816444),
#  ('word', -0.40456623164314731),
#  ('stay', -0.40440634675992232),
#  ('maybe', -0.40439730234733418),
#  ('else', -0.40338220795915497),
#  ('exploitation', -0.40187443997743588),
#  ('car', -0.40070157409213092),
#  ('horror', -0.40013052512218644),
#  ('b', -0.39790753177208499),
#  ('writing', -0.39780223536259535),
#  ('just', -0.39525281155049552),
#  ('t', -0.39476668409199184),
#  ('camera', -0.39328697165333754),
#  ('attack', -0.39248994924503094),
#  ('boat', -0.39230702353065322),
#  ('edited', -0.38641691313746984),
#  ('cuts', -0.38421999949442825),
#  ('entire', -0.3838364903813864),
#  ('single', -0.38372512147175847),
#  ('decided', -0.38187910910228517),
#  ('shame', -0.37698021009947791),
#  ('lighting', -0.37554342824311515),
#  ('bloody', -0.37520145046833753),
#  ('talking', -0.37501473458473666),
#  ('concept', -0.37351350830156199),
#  ('let', -0.37279174717315233),
#  ('cop', -0.37197235932705008),
#  ('manage', -0.37187416367212889),
#  ('lines', -0.37123716791846123),
#  ('off', -0.37034478723835357),
#  ('could', -0.36993236514149658),
#  ('happens', -0.36859457229983666),
#  ('anybody', -0.36529906638282966),
#  ('door', -0.36511381258459702),
#  ('drop', -0.36497374675342742),
#  ('van', -0.36354782322649443),
#  ('shots', -0.36257012953665285),
#  ('non', -0.36208036250564041),
#  ('produce', -0.36197999616842552),
#  ('wanted', -0.36188656504378053),
#  ('mention', -0.36146824251101212),
#  ('kill', -0.3604154739423362),
#  ('anywhere', -0.35907206853845391),
#  ('context', -0.35760908693052934),
#  ('make', -0.3574012922546686),
#  ('thinks', -0.3561192340050095),
#  ('ask', -0.35555071672645144),
#  ('gun', -0.35538100371075287),
#  ('nasty', -0.35454501768090746),
#  ('original', -0.35315115473999031),
#  ('suffers', -0.35184401666906684),
#  ('excited', -0.35139788683788858),
#  ('die', -0.35117202574150214),
#  ('totally', -0.35091766180893602),
#  ('fell', -0.35036134878188002),
#  ('dead', -0.34982161653946126),
#  ('then', -0.34911217155703261),
#  ('humans', -0.3483066942682157),
#  ('theatre', -0.3483066942682157),
#  ('nor', -0.34747785045781504),
#  ('incredibly', -0.34740130715340317),
#  ('apparent', -0.34646676734620863),
#  ('guys', -0.34568889172613693),
#  ('suddenly', -0.34540086736551423),
#  ('driving', -0.34409616173187224),
#  ('better', -0.34382499115062337),
#  ('steven', -0.34358970439007686),
#  ('describe', -0.3427092630767607),
#  ('murdered', -0.3417492937220567),
#  ('anti', -0.34148477844475716),
#  ('cars', -0.34016000970039767),
#  ('intelligence', -0.33961854231057792),
#  ('hours', -0.33891424027676464),
#  ('body', -0.33717920024203291),
#  ('head', -0.33402534406458012),
#  ('act', -0.33400614412601948),
#  ('somehow', -0.33330266185993379),
#  ('biggest', -0.33314444652853825),
#  ('footage', -0.33173413878642899),
#  ('straight', -0.33171221176685833),
#  ('isn', -0.33097090135074575),
#  ('rating', -0.32983993522803523),
#  ('re', -0.32977714161883409),
#  ('ruin', -0.32803336797534832),
#  ('slow', -0.3243692144499693),
#  ('filming', -0.32340015505386011),
#  ('desert', -0.32277339226305102),
#  ('something', -0.32062297549865787),
#  ('reviews', -0.32025824288639371),
#  ('should', -0.31969594069764495),
#  ('chose', -0.31952267830743969),
#  ('fault', -0.31935341628943226),
#  ('normally', -0.31845373111853459),
#  ('loud', -0.31845373111853459),
#  ('decide', -0.31800580277957829),
#  ('exception', -0.31683865674323652),
#  ('enough', -0.31664015381022231),
#  ('storyline', -0.31603729820690607),
#  ('sounds', -0.31577635334781817),
#  ('confused', -0.31559086056885755),
#  ('ill', -0.31551687144522494),
#  ('hair', -0.31546163655885662),
#  ('want', -0.31530595819005153),
#  ('myself', -0.31469008346923083),
#  ('actually', -0.31346415811736705),
#  ('doing', -0.31320296173390433),
#  ('directing', -0.31309178797714921),
#  ('plane', -0.31309178797714921),
#  ('pretty', -0.31144525106350979),
#  ('million', -0.30975802415098064),
#  ('creatures', -0.30942205908818682),
#  ('wrote', -0.30905693203651446),
#  ('ship', -0.3078847797693004),
#  ('cutting', -0.30715417586460125),
#  ('looking', -0.3060312111199775),
#  ('running', -0.30475637597362876),
#  ('turning', -0.30466040898619884),
#  ('suit', -0.30458388325438412),
#  ('eating', -0.30448919076816211),
#  ('drunk', -0.30368241379822203),
#  ('d', -0.30324511194365289),
#  ('piece', -0.30287993336121233),
#  ('dies', -0.302810954048081),
#  ('simply', -0.30254118685553072),
#  ('unable', -0.30186670744373734),
#  ('ideas', -0.30142124833508488),
#  ('cares', -0.30048634469776869),
#  ('kinda', -0.30042109822921076),
#  ('whole', -0.29982182700239146),
#  ('material', -0.29918967930326068),
#  ('name', -0.29896517668451678),
#  ('try', -0.29820345119331371),
#  ('female', -0.29817275798725246),
#  ('needed', -0.29793857261897005),
#  ('theater', -0.2968467471013444),
#  ('doesn', -0.29578865998476939),
#  ('forced', -0.29562913414431269),
#  ('kept', -0.2954642128938359),
#  ('stuff', -0.29513922855986297),
#  ('watching', -0.29477789543324995),
#  ('animal', -0.29450803752218074),
#  ('laugh', -0.29447327002978269),
#  ('making', -0.29261061865293003),
#  ('believe', -0.29187495071181685),
#  ('point', -0.29112067868132568),
#  ('there', -0.29068735719475253),
#  ('box', -0.2904255583975317),
#  ('hill', -0.29008303398931906),
#  ('kid', -0.28865436227072017),
#  ('angry', -0.2876820724517809),
#  ('cops', -0.2876820724517809),
#  ('anyway', -0.28663768593387468),
#  ('sort', -0.28451249769050191),
#  ('do', -0.28412334983478682),
#  ('or', -0.2840541856015209),
#  ('stop', -0.28230282333204487),
#  ('forward', -0.28141245943818544),
#  ('intended', -0.28016888910099774),
#  ('only', -0.27765533221657424),
#  ('keaton', -0.27625337662815824),
#  ('your', -0.2760987334669438),
#  ('stuck', -0.27602498790956814),
#  ('insane', -0.27559002668675231),
#  ('yourself', -0.27471783666506644),
#  ('might', -0.27450033574971666),
#  ('five', -0.27394044459948447),
#  ('they', -0.27376557446680982),
#  ('boyfriend', -0.27304052245883287),
#  ('names', -0.27277866694920599),
#  ('mike', -0.27115277050057041),
#  ('absolutely', -0.26963529000470737),
#  ('beyond', -0.26951810182410973),
#  ('movie', -0.26914869279585191),
#  ('rest', -0.26894162092396373),
#  ('bodies', -0.26888957310241351),
#  ('jump', -0.26826398659467943),
#  ('average', -0.26826398659467943),
#  ('if', -0.26736730305175055),
#  ('started', -0.26530436213848768),
#  ('hadn', -0.26488315748697489),
#  ('would', -0.26464087330508307),
#  ('count', -0.26286690333205692),
#  ('going', -0.26283871939239123),
#  ('falls', -0.262364264467491),
#  ('evidence', -0.2615709284480951),
#  ('sell', -0.26007680635989217),
#  ('imagine', -0.25683739710068243),
#  ('free', -0.2567819104630395),
#  ('talks', -0.25593337413720063),
#  ('hate', -0.25518290505882646),
#  ('proper', -0.2546422183735807),
#  ('speak', -0.25423413838424086),
#  ('designed', -0.25378052077609958),
#  ('military', -0.25241393361432296),
#  ('rescue', -0.25241393361432296),
#  ('absolute', -0.25131442828090605),
#  ('start', -0.2507168782183094),
#  ('bank', -0.25035611483909453),
#  ('sound', -0.24977537449500295),
#  ('corny', -0.24934592370823383),
#  ('sense', -0.24716640355805958),
#  ('getting', -0.24585291825538402),
#  ('sean', -0.24550045841548626),
#  ('result', -0.24527940694643602),
#  ('clothes', -0.24512245803298496),
#  ('hunter', -0.24387944979338794),
#  ('awkward', -0.24312605090154804),
#  ('begin', -0.243077766215027),
#  ('production', -0.24252253954453232),
#  ('said', -0.24160561415394513),
#  ('woods', -0.2411620568168881),
#  ('treated', -0.2411620568168881),
#  ('turned', -0.2411620568168881),
#  ('merely', -0.24070987503210897),
#  ('chase', -0.23856802163984142),
#  ('bizarre', -0.23758423546900409),
#  ('seems', -0.23708105915799141),
#  ('parody', -0.23590580292806104),
#  ('walks', -0.23582871084152554),
#  ('alex', -0.23483959107740107),
#  ('carry', -0.23419338750079477),
#  ('tell', -0.23388929748780826),
#  ('reviewers', -0.23326168147979442),
#  ('plots', -0.23262229526875347),
#  ('wait', -0.23191004452639233),
#  ('calls', -0.2318016140573243),
#  ('bed', -0.23017757797158975),
#  ('gags', -0.23001643060197186),
#  ('christmas', -0.22892391422970923),
#  ('filmmaker', -0.22853439994908623),
#  ('did', -0.22843419066576851),
#  ('store', -0.22834737918923681),
#  ('expected', -0.22825865198098019),
#  ('were', -0.22706725297124281),
#  ('surely', -0.22638154658798512),
#  ('list', -0.22621575035117997),
#  ('finished', -0.2261241794523475),
#  ('student', -0.22543976357456),
#  ('cannot', -0.2251948340847672),
#  ('costume', -0.225161715470447),
#  ('so', -0.22493351490142224),
#  ('shock', -0.2243124585191916),
#  ('appeal', -0.22414807174021528),
#  ('answer', -0.22314355131420971),
#  ('laughs', -0.22314355131420971),
#  ('called', -0.22282953027221966),
#  ('floor', -0.22154226994723586),
#  ('weird', -0.22110758182911117),
#  ('talk', -0.21940323169848655),
#  ('quick', -0.21916212601502486),
#  ('drag', -0.21887915252775217),
#  ('meant', -0.21875437089544664),
#  ('twist', -0.21868920096482944),
#  ('ii', -0.21813100949066541),
#  ('like', -0.21786298170091856),
#  ('flashbacks', -0.21752029375984758),
#  ('girlfriend', -0.21749381877209073),
#  ('pacing', -0.2170645052378275),
#  ('students', -0.21691300156357363),
#  ('possible', -0.21684573472721974),
#  ('ended', -0.21667103680859223),
#  ('happening', -0.21492271816935263),
#  ('plan', -0.21459649073575138),
#  ('huge', -0.21457615002891103),
#  ('starts', -0.21392689620928568),
#  ('bright', -0.21325879208166776),
#  ('title', -0.21322909425703121),
#  ('kind', -0.21280086053975453),
#  ('say', -0.2113090936672069),
#  ('machine', -0.21065206342018061),
#  ('actual', -0.21010112090103036),
#  ('mom', -0.20840126957700628),
#  ('already', -0.20784128300205013),
#  ('product', -0.20763936477824449),
#  ('villain', -0.20740699577522378),
#  ('gang', -0.20499035660666751),
#  ('read', -0.20437440339963553),
#  ('ve', -0.20397531312781356),
#  ('impression', -0.20316508438332337),
#  ('religion', -0.20236848873924534),
#  ('happened', -0.201421728167374),
#  ('left', -0.20114604842066713),
#  ('reviewer', -0.20067069546215111),
#  ('talent', -0.2000211338933556),
#  ('fair', -0.19845093872383832),
#  ('group', -0.19793578459550545),
#  ('been', -0.19677849776538223),
#  ('because', -0.19676282675055351),
#  ('shot', -0.19663307118721049),
#  ('happen', -0.19602762269832177),
#  ('etc', -0.19232618776388136),
#  ('offer', -0.19105523676270922),
#  ('folks', -0.19077826681217808),
#  ('clearly', -0.18966553104971309),
#  ('prove', -0.18924199963852842),
#  ('nightmare', -0.18924199963852842),
#  ('run', -0.18924199963852842),
#  ('expectations', -0.18867654867633193),
#  ('add', -0.18820792199056538),
#  ('writer', -0.18805223150293959),
#  ('girls', -0.18716711442747755),
#  ('have', -0.18493987859765385),
#  ('felt', -0.18376144185194221),
#  ('cause', -0.18369235892773331),
#  ('speaking', -0.18322694390876715),
#  ('picked', -0.18232155679395459),
#  ('was', -0.18196408389534008),
#  ('religious', -0.18113882454490515),
#  ('am', -0.18075415835394182),
#  ('st', -0.18038169197612808),
#  ('line', -0.18035884762610591),
#  ('went', -0.17956500824982596),
#  ('funny', -0.17907341307143876),
#  ('involves', -0.17904823144898543),
#  ('reporter', -0.1788792126029819),
#  ('jones', -0.17780687643942797),
#  ('evil', -0.17750471391489595),
#  ('depressing', -0.17745536714278173),
#  ('basic', -0.17738675650810648),
#  ('bits', -0.17733401528291554),
#  ('got', -0.17721168364168408),
#  ('ever', -0.17688127930942568),
#  ('deliver', -0.17675051174449924),
#  ('had', -0.17654213228475038),
#  ('comparison', -0.17645643734155653),
#  ('soldiers', -0.17622663152645815),
#  ('far', -0.17579564555899366),
#  ('news', -0.17567701407528602),
#  ('trailer', -0.17551550232495516),
#  ('executed', -0.17471695740873536),
#  ('laughing', -0.17468528226896612),
#  ('managed', -0.17455955145846544),
#  ('actors', -0.17439246796391672),
#  ('ten', -0.1743533871447778),
#  ('rated', -0.1743533871447778),
#  ('cartoon', -0.17290655785935274),
#  ('interest', -0.172741919937141),
#  ('made', -0.17211179740153834),
#  ('example', -0.17109449420017114),
#  ('correct', -0.17081773231247005),
#  ('finish', -0.17072980863016957),
#  ('skin', -0.17022114985986722),
#  ('cult', -0.170181802243344),
#  ('standing', -0.16907633004393399),
#  ('appear', -0.16813692180199821),
#  ('look', -0.16774210703079734),
#  ('ll', -0.16699607161021296),
#  ('impossible', -0.16671365912796371),
#  ('shouldn', -0.16606103592217425),
#  ('get', -0.16472856510561967),
#  ('director', -0.16460009570159942),
#  ('appears', -0.16446004948611959),
#  ('site', -0.16430305129127629),
#  ('bet', -0.16430305129127629),
#  ('cost', -0.16400297627026997),
#  ('fast', -0.16312554158795683),
#  ('know', -0.16283656348022271),
#  ('generally', -0.16275146059985746),
#  ('comment', -0.1626855822770957),
#  ('using', -0.16265478983355891),
#  ('considering', -0.16211884947643523),
#  ('direction', -0.16063332240231395),
#  ('give', -0.16029495152997603),
#  ('fire', -0.15906469462968739),
#  ('army', -0.15892395857991595),
#  ('be', -0.15798628209048571),
#  ('hot', -0.15776079205135796),
#  ('usually', -0.15730625202606813),
#  ('main', -0.15579136928471821),
#  ('quality', -0.15557823181844374),
#  ('fly', -0.15548490284039498),
#  ('anyone', -0.15532673547262923),
#  ('reading', -0.15505443045361508),
#  ('victim', -0.15415067982725836),
#  ('steal', -0.15415067982725836),
#  ('this', -0.15398777357944343),
#  ('attractive', -0.15327387135372381),
#  ('teacher', -0.153164972502499),
#  ('vehicle', -0.15283920422944755),
#  ('hide', -0.15267684020895775),
#  ('target', -0.15267684020895775),
#  ('laughed', -0.15246859364427351),
#  ('aside', -0.15219181534192538),
#  ('drive', -0.15207814022528598),
#  ('hospital', -0.15154989812720093),
#  ('around', -0.14901719832801943),
#  ('hurt', -0.14686024656457905),
#  ('kids', -0.14676313783414227),
#  ('middle', -0.14670607512563388),
#  ('shooting', -0.14639870302294031),
#  ('afraid', -0.14603155538875415),
#  ('space', -0.14595391262307983),
#  ('instance', -0.14558531696833527),
#  ('responsible', -0.14518200984449783),
#  ('male', -0.14439450488189357),
#  ('audience', -0.1440154579332153),
#  ('built', -0.14370672066617501),
#  ('entertained', -0.14370672066617501),
#  ('allow', -0.1431008436406733),
#  ('p', -0.1431008436406733),
#  ('acts', -0.1423719806346456),
#  ('worked', -0.14197026127038723),
#  ('i', -0.14030709947871625),
#  ('gets', -0.14005370021822033),
#  ('build', -0.13858616328614667),
#  ('scenes', -0.137591946634783),
#  ('degree', -0.13747099062860288),
#  ('literally', -0.13696585507315742),
#  ('not', -0.13617293990213197),
#  ('feet', -0.13580154115906176),
#  ('sure', -0.13422947293210352),
#  ('really', -0.13412471547801144),
#  ('revenge', -0.13353139262452263),
#  ('fights', -0.13353139262452263),
#  ('down', -0.13324399500794468),
#  ('less', -0.13312981307291075),
#  ('essentially', -0.13248918304607887),
#  ('too', -0.13168492261793927),
#  ('ground', -0.13049648892936863),
#  ('behavior', -0.13045288839743521),
#  ('crash', -0.12953405219190228),
#  ('routine', -0.12953405219190228),
#  ('movies', -0.1290596132331292),
#  ('lets', -0.12479077281378824),
#  ('standards', -0.12445417447340598),
#  ('drug', -0.12422899996220906),
#  ('put', -0.12194846863544662),
#  ('train', -0.12180487388420344),
#  ('person', -0.1217803760890038),
#  ('types', -0.12160713209478687),
#  ('missing', -0.12136085700426748),
#  ('cat', -0.12080483808529992),
#  ('standard', -0.12041254019540824),
#  ('whenever', -0.11865754380131599),
#  ('points', -0.11836460008103292),
#  ('c', -0.11819295572771066),
#  ('lee', -0.11807310092310179),
#  ('few', -0.11789889037469639),
#  ('repeated', -0.11778303565638351),
#  ('away', -0.11761286633750097),
#  ('given', -0.11701645838618796),
#  ('earth', -0.1165109326989304),
#  ('expecting', -0.11577540599189566),
#  ('loose', -0.11523526357758476),
#  ('anymore', -0.11423818968984367),
#  ('need', -0.11412481365141453),
#  ('theaters', -0.11365931847252136),
#  ('involved', -0.11339898654784904),
#  ('book', -0.11251524472152456),
#  ('school', -0.11223339494558832),
#  ('bear', -0.11211729812070612),
#  ('convinced', -0.11122563511022437),
#  ('worthy', -0.11060987154397003),
#  ('women', -0.11024367848289833),
#  ('some', -0.10997289679343757),
#  ('seem', -0.1095346711142603),
#  ('commercial', -0.10889408823913739),
#  ('connection', -0.10863384100279541),
#  ('claim', -0.10821358464023272),
#  ('go', -0.10753029113910025),
#  ('display', -0.10742024862083688),
#  ('interesting', -0.1068448962016182),
#  ('how', -0.10683106927783201),
#  ('case', -0.1057736534451527),
#  ('shocked', -0.10536051565782628),
#  ('unfortunate', -0.10536051565782628),
#  ('taste', -0.10536051565782628),
#  ('says', -0.10459977009051714),
#  ('seemingly', -0.10354067894084033),
#  ('extremely', -0.10299084630250786),
#  ('national', -0.10204925435417023),
#  ('major', -0.10148939617028299),
#  ('window', -0.10125373370517292),
#  ('couple', -0.10020016509851665),
#  ('here', -0.099614109639602683),
#  ('related', -0.099090902644230885),
#  ('blow', -0.099090902644230885),
#  ('desperate', -0.098845834636632601),
#  ('out', -0.098835710053638726),
#  ('industry', -0.098630603441627301),
#  ('sheriff', -0.098440072813252524),
#  ('waiting', -0.098440072813252524),
#  ('ed', -0.098238439583413217),
#  ('credit', -0.098192026179213729),
#  ('up', -0.097737801282270872),
#  ('mental', -0.097163748453647739),
#  ('doctor', -0.096228032094553773),
#  ('over', -0.094496277096124445),
#  ('turn', -0.092781733450966214),
#  ('thought', -0.092588636287735948),
#  ('scene', -0.092579536406792562),
#  ('park', -0.091708426489499006),
#  ('yes', -0.091447487318580711),
#  ('end', -0.091390991059127402),
#  ('sea', -0.090971778205726758),
#  ('front', -0.090818674018028123),
#  ('question', -0.09057281550344691),
#  ('exactly', -0.090514007540831859),
#  ('them', -0.090400284305156828),
#  ('than', -0.090191141625864946),
#  ('facts', -0.089345100335849983),
#  ('can', -0.089044731832723517),
#  ('at', -0.088945592068134627),
#  ('asked', -0.088192712035460849),
#  ('ability', -0.088162787594671596),
#  ('fact', -0.088050029802049096),
#  ('hand', -0.087565854408881483),
#  ('special', -0.08618677069238842),
#  ('about', -0.086158934690972508),
#  ('hero', -0.085359848951156753),
#  ('likely', -0.085359848951156753),
#  ('what', -0.084833314172418586),
#  ('use', -0.084307106459993966),
#  ('plus', -0.083769883065458822),
#  ('another', -0.082745261934922903),
#  ('crazy', -0.082238098236972118),
#  ('realized', -0.082064953054304168),
#  ('me', -0.081545203437548994),
#  ('moon', -0.081125544812368458),
#  ('crew', -0.080887659139100676),
#  ('much', -0.080551567592101206),
#  ('apart', -0.080299942401642968),
#  ('drugs', -0.08004270767353637),
#  ('allowed', -0.08004270767353637),
#  ('bought', -0.078643127319113104),
#  ('believed', -0.076961041136128325),
#  ('amount', -0.076805411223745054),
#  ('trouble', -0.076665881747917011),
#  ('dying', -0.076470363991838028),
#  ('curious', -0.076372978784573969),
#  ('lead', -0.076372978784573969),
#  ('self', -0.075985906977921985),
#  ('factor', -0.073427468554817202),
#  ('sheer', -0.072906770808087787),
#  ('people', -0.070465330089114209),
#  ('appeared', -0.070109566187026587),
#  ('gotten', -0.069958588606910344),
#  ('alone', -0.069773816470022842),
#  ('conclusion', -0.069557683701910109),
#  ('jennifer', -0.069526062648610221),
#  ('ends', -0.06913321251588149),
#  ('concerned', -0.06693948267510938),
#  ('br', -0.066814541811795441),
#  ('therefore', -0.065695259265394892),
#  ('gave', -0.064113982816612014),
#  ('used', -0.062820012379870505),
#  ('choose', -0.061693569005339899),
#  ('grace', -0.06099451270284191),
#  ('through', -0.060795534858736774),
#  ('doubt', -0.060784891069121855),
#  ('hard', -0.059987997721448721),
#  ('quickly', -0.059485453286179997),
#  ('everything', -0.059372273499969),
#  ('amusing', -0.0589561671331197),
#  ('itself', -0.058915883536594729),
#  ('besides', -0.058553308751574135),
#  ('suggest', -0.058372006221907212),
#  ('professor', -0.05770831762064673),
#  ('goes', -0.05734576747047327),
#  ('cable', -0.057158413839948637),
#  ('danger', -0.056089466651043585),
#  ('program', -0.055350095083164956),
#  ('violence', -0.054958884280757472),
#  ('giving', -0.054840915699586129),
#  ('admit', -0.054764085409974878),
#  ('science', -0.054658412537864083),
#  ('excitement', -0.054558984250434366),
#  ('that', -0.054214927394440157),
#  ('according', -0.054067221270275821),
#  ('same', -0.053800291231053655),
#  ('being', -0.053265237545203771),
#  ('figure', -0.052782699577919055),
#  ('naturally', -0.052446475372542545),
#  ('written', -0.051991906717891792),
#  ('take', -0.051878260768665189),
#  ('girl', -0.051185374895386888),
#  ('mostly', -0.051074929936415395),
#  ('you', -0.050726621059551294),
#  ('native', -0.050430853626891967),
#  ('ghost', -0.049596941139372061),
#  ('move', -0.049596941139372061),
#  ('onto', -0.048790164169432056),
#  ('putting', -0.048790164169432056),
#  ('robin', -0.048396540861850211),
#  ('.', -0.048201217552322095),
#  ('lies', -0.048119248344198458),
#  ('holding', -0.0478560211776351),
#  ('opening', -0.046995368593408811),
#  ('mini', -0.046956983087770979),
#  ('pull', -0.046792161506758939),
#  ('club', -0.04630456804168627),
#  ('entirely', -0.045120435280469544),
#  ('but', -0.045027910080529768),
#  ('energy', -0.044171218313137424),
#  ('pulled', -0.043802622658392888),
#  ('content', -0.043722811013831575),
#  ('black', -0.04327125394063458),
#  ('watched', -0.042940407234028956),
#  ('ancient', -0.042925044717033886),
#  ('break', -0.042420715883952138),
#  ('model', -0.041499730906752734),
#  ('long', -0.041153300579087018),
#  ('overly', -0.040166041725334757),
#  ('double', -0.04000533461369913),
#  ('feels', -0.039511312273842303),
#  ('rather', -0.039507698375512101),
#  ('structure', -0.038839833316263894),
#  ('e', -0.038589997269868975),
#  ('kick', -0.037740327982847086),
#  ('saturday', -0.036367644170874833),
#  ('watch', -0.036138145207828758),
#  ('matters', -0.035718082602079232),
#  ('every', -0.035691146937911457),
#  ('mentioned', -0.035464709572282656),
#  ('pick', -0.035401927050915952),
#  ('casting', -0.035316671924899845),
#  ('understand', -0.034066554563606195),
#  ('twenty', -0.033447934067540132),
#  ('to', -0.032835251600582795),
#  ('probably', -0.032374396659016001),
#  ('psycho', -0.032260862218221435),
#  ('words', -0.031676856653570201),
#  ('level', -0.031155167779795576),
#  ('member', -0.030583423372080278),
#  ('blind', -0.03053672386008165),
#  ('bigger', -0.02985296314968116),
#  ('deadly', -0.02985296314968116),
#  ('near', -0.029128272923023713),
#  ('check', -0.028610534041265775),
#  ('air', -0.028170876966696335),
#  ('heroine', -0.027587956518829053),
#  ('motion', -0.026668247082161294),
#  ...]

# %%
print("Positive-to-negative ratio for 'the' = {}".format(PN_ratios["the"]))
print("Positive-to-negative ratio for 'and' = {}".format(PN_ratios["and"]))
print("Positive-to-negative ratio for 'amazing' = {}".format(PN_ratios["amazing"]))
print("Positive-to-negative ratio for 'excellent' = {}".format(PN_ratios["excellent"]))
print("Poitives-to-negative ratio for 'terrible' = {}".format(PN_ratios["terrible"]))
print("Positive-to-negative ratio for 'bad' = {}".format(PN_ratios["bad"]))
# Out:
# Positive-to-negative ratio for 'the' = 0.05902881460535952
# Positive-to-negative ratio for 'and' = 0.18746169236813243
# Positive-to-negative ratio for 'amazing' = 1.3957911086571477
# Positive-to-negative ratio for 'excellent' = 1.4673278545675326
# Poitives-to-negative ratio for 'terrible' = -1.7283898552954657
# Positive-to-negative ratio for 'bad' = -1.3560837995970472

# %% [markdown]
# Checking out these ratios, we see that if a review contains words like "wonderfully", "refreshing", "delightful", and "beautifully"(the greatest numbers in PN_ratios), then it is most likely a positive review. We also see that if a review contains words like "unfunny", "waste", "lousy", "awful", "sucks", and "pathetic", then it is most probably a negative review.

# %% [markdown]
# # Processing reviews into input and creating our Neural Network
#
# We will encapsulate the network in a class.
#
# We need to create a method to input the reviews into our network, so what we'll do is:
# - Create a vocabulary containing all of the words in all of the reviews.
# - Assign the vocabulary an index
# - Create a vocab input layer of zeros the same length as the vocabulary
# - Input a review by inputting the amount of times every word is used in that review at the vocab word indice of the vocab input layer.
#
# So this network object should be able to:
#   - Take as input the number of hidden nodes and the learning rate to build and train the network
#   - Take as input reviews and labels to train on
#   - Test the accuracy of the network against any given reviews
#   - Predict the sentiment classification of any given movie review
#
# This simple network will be built from scratch without using any deep learning libraries(tensorflow, keras..) only numpy.

# %%
import time                                      ##### v1 #####                                                  
import sys
import numpy as np
from collections import Counter

class SentimentNetwork:
    def __init__(self, train_reviews, train_labels, hidden1_nodes = 10, hidden2_nodes = 10):
        np.random.seed(1)
        
        ### creating a network vocabulary with all of the words from all of the training reviews ###
        network_vocab = set()
        for review in train_reviews:
            for word in review.split(' '):
                network_vocab.add(word)
                
        self.vocab_index = {} ### creating an index for network vocab ###
        for index,word in enumerate(network_vocab):
            self.vocab_index[word] = index
        
        ### initializing weights ###
        self.weights_i_1 = np.zeros((len(network_vocab), hidden1_nodes))
        self.weights_1_2 = np.random.normal(0.0, hidden1_nodes**-0.5, (hidden1_nodes, hidden2_nodes))
        self.weights_2_o = np.random.normal(0.0, hidden2_nodes**-0.5, (hidden2_nodes, 1))
        
        self.train_reviews = train_reviews
        self.train_labels = train_labels
        
    ### sigmoid function ###
    def sigmoid(self,x):
        
        return 1/(1.0+np.exp(-x))
        
    ### derivative of sigmoid function ###
    def sigmoid_output_derivative(self,output):
        
        return output*(1-output)
        


    def train(self, learning_rate = 0.1, epochs = 15):
            
        assert(len(self.train_reviews) == len(self.train_labels))
        
            
        correct_so_far = 0
        
        ### process labels from "POSITIVE" and "NEGATIVE" to 1 and 0 ###
        for i in range(len(self.train_labels)):
            if self.train_labels[i] == "POSITIVE":
                self.train_labels[i] = 1
            else:
                self.train_labels[i] = 0
                
        
        ### create input layer ###
        layer_i = np.zeros((1, len(self.vocab_index)))
        
        start = time.time()
        ### looping through epochs ###
        for i in range(epochs):
            print(" ")
            print("\t Epoch #{}:".format(i+1))
            print("")
            for item in range(len(self.train_reviews)):
            
                ### get current review ###
                creview = self.train_reviews[item]
                clabel = self.train_labels[item]    
                    
                ### update input layer for current review ###
                layer_i *= 0 
                for word in creview.split(" "):
                    if word in self.vocab_index:
                        layer_i[0, self.vocab_index[word]] += 1
                
                ### FORWARD PASS ###
                layer_1 = np.dot(layer_i, self.weights_i_1)
                layer_2 = np.dot(layer_1, self.weights_1_2)
                output = self.sigmoid(np.dot(layer_2, self.weights_2_o))
            
                ### BACKPROPOGATION ###
                output_error = clabel - output
            
                output_error_term = output_error * self.sigmoid_output_derivative(output) 
            
                hidden2_error_term = output_error_term.dot(self.weights_2_o.T) * 1 # just the derivative
            
                hidden1_error_term = hidden2_error_term.dot(self.weights_1_2.T) * 1 # just the derivative
            
                ### updating weights on every review ###
                self.weights_2_o += layer_2.T.dot(output_error_term) * learning_rate
                self.weights_1_2 += layer_1.T.dot(hidden2_error_term) * learning_rate
                self.weights_i_1 += layer_i.T.dot(hidden1_error_term) * learning_rate
                
                ### for training progress ###
                if abs(output_error) < 0.5:
                    correct_so_far += 1
                    
                elapsed_time = float(time.time() - start)
                progress = ((100.0 * (item+1+(i*len(self.train_reviews)))/(len(self.train_reviews)*epochs)))
                
                if progress % 5 == 0:
                    sys.stdout.write("\rProgress:" + str(progress)[:4] + "%" \
                                    + " | #Correct:" + str(correct_so_far) + "--> #Trained:" + str((item+1)+(i*len(self.train_reviews))) \
                                    + " | Training Accuracy:" + str(correct_so_far * 100.0 / (float(item+1)+(i*len(self.train_reviews))))[:4] + "%" \
                                    + " | Average Training speed per epoch: " + str(elapsed_time/(i+1))[:4] + " seconds")
                
    def run(self, review):
        
        ### create input layer ###
        layer_i = np.zeros((1, len(self.vocab_index))) 
        for word in review.split(" "):
            if word in self.vocab_index:    
                layer_i[0, self.vocab_index[word]] += 1
            
        ### FORWARD PASS ###
        layer_1 = np.dot(layer_i, self.weights_i_1)
        layer_2 = np.dot(layer_1, self.weights_1_2)
        output = self.sigmoid(np.dot(layer_2, self.weights_2_o))
        
        if output >= 0.5:
            return "POSITIVE"
        else:
            return "NEGATIVE"
                
    
    def test(self, testing_reviews, testing_labels):
        
        correct = 0

        start = time.time()
        
        ### "self.run" each testing review through the network and count how many it got correct ###
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if (pred == testing_labels[i]):
                correct += 1
            
            
            ### print out accuracy and speed ###
            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            if i == (len(testing_reviews)-1):
                sys.stdout.write("\rProgress: " + str(100 * i/float(len(testing_reviews)-1))[:4] + "%" \
                                 + "\t#Correct: " + str(correct) + "\t#Tested:" + str(i+1))
        print("")
        print("Testing Accuracy: " + str(100*correct/len(testing_reviews)) + "%")

# %% [markdown]
# Since we have 25000 movie reviews to work with, the first 24000 will be used for training, and the last 1000 for testing

# %%
network_v1 = SentimentNetwork(reviews[:-1000], labels[:-1000])

# %% [markdown]
# Next I'll run the training with a learning rate of 0.1 and 5 epochs:

# %%
network_v1.train(learning_rate = 0.1, epochs = 5)
# Out:
#
# 	 Epoch #1:
#
# Progress:20.0% | #Correct:15412--> #Trained:24000 | Training Accuracy:64.2% | Average Training speed per epoch: 108. seconds
# 	 Epoch #2:
#
# Progress:40.0% | #Correct:33768--> #Trained:48000 | Training Accuracy:70.3% | Average Training speed per epoch: 107. seconds
# 	 Epoch #3:
#
# Progress:60.0% | #Correct:52861--> #Trained:72000 | Training Accuracy:73.4% | Average Training speed per epoch: 107. seconds
# 	 Epoch #4:
#
# Progress:80.0% | #Correct:72513--> #Trained:96000 | Training Accuracy:75.5% | Average Training speed per epoch: 107. seconds
# 	 Epoch #5:
#
# Progress:100.% | #Correct:92367--> #Trained:120000 | Training Accuracy:76.9% | Average Training speed per epoch: 108. seconds

# %% [markdown]
# And Testing the network on the last 1000 reviews....

# %%
network_v1.test(reviews[-1000:], labels[-1000:])
# Out:
# Progress: 100.%	#Correct: 837	#Tested:1000
# Testing Accuracy: 83.7%

# %% [markdown]
# # Network Efficiency
#
# The network trained well but it is very slow. Maybe we can make the network train faster by reducing the size of the network vocabulary, we don't need uncommon words so much anyway.
#
# I will rebuild and test the network with a common_cutoff varible that is the amount of times a word has to be found in all training reviews in order for the word to make it into the network vocabulary.

# %%
import time                                      ##### v2 ##### 
import sys
import numpy as np
from collections import Counter

class SentimentNetwork:
    def __init__(self, train_reviews, train_labels, hidden1_nodes = 10, hidden2_nodes = 10, common_cutoff = 50):
        np.random.seed(1)
        
        ### creating total word count for all training reviews ###
        word_count = Counter()
        for review in train_reviews:
            for word in review.split(' '):
                word_count[word] += 1
        network_vocab = set()                     ####       MORE EFFICIENT AND GENERAL         ####
        for word in word_count:                   ####   <--------------                        #### 
            if word_count[word] >= common_cutoff: #### selecting common words for network vocab ####
                network_vocab.add(word)
                
        self.vocab_index = {} ### creating an index for network vocab ###
        for index,word in enumerate(network_vocab):
            self.vocab_index[word] = index
        
        ### initializing weights ###
        self.weights_i_1 = np.zeros((len(network_vocab), hidden1_nodes))
        self.weights_1_2 = np.random.normal(0.0, hidden1_nodes**-0.5, (hidden1_nodes, hidden2_nodes))
        self.weights_2_o = np.random.normal(0.0, hidden2_nodes**-0.5, (hidden2_nodes, 1))
        
        self.train_reviews = train_reviews
        self.train_labels = train_labels
        
    ### sigmoid function ###
    def sigmoid(self,x):
        
        return 1/(1.0+np.exp(-x))
        
    ### derivative of sigmoid function ###
    def sigmoid_output_derivative(self,output):
        
        return output*(1-output)
        


    def train(self, learning_rate = 0.1, epochs = 15):
            
        assert(len(self.train_reviews) == len(self.train_labels))
        
            
        correct_so_far = 0
        
        ### process labels from "POSITIVE" and "NEGATIVE" to 1 and 0 ###
        for i in range(len(self.train_labels)):
            if self.train_labels[i] == "POSITIVE":
                self.train_labels[i] = 1
            else:
                self.train_labels[i] = 0
                
        
        ### create input layer ###
        layer_i = np.zeros((1, len(self.vocab_index)))
        
        start = time.time()
        ### looping through epochs ###
        for i in range(epochs):
            print(" ")
            print("Epoch #{}:".format(i+1))
            print("")
            for item in range(len(self.train_reviews)):
            
                ### get current review ###
                creview = self.train_reviews[item]
                clabel = self.train_labels[item]    
                    
                ### update input layer for current review ###
                layer_i *= 0 
                for word in creview.split(" "):                
                    if word in self.vocab_index:                 
                        layer_i[0, self.vocab_index[word]] += 1               
                
                ### FORWARD PASS ###
                layer_1 = np.dot(layer_i, self.weights_i_1)
                layer_2 = np.dot(layer_1, self.weights_1_2)
                output = self.sigmoid(np.dot(layer_2, self.weights_2_o))
            
                ### BACKPROPOGATION ###
                output_error = clabel - output
            
                output_error_term = output_error * self.sigmoid_output_derivative(output) 
            
                hidden2_error_term = output_error_term.dot(self.weights_2_o.T) * 1 # just the derivative
            
                hidden1_error_term = hidden2_error_term.dot(self.weights_1_2.T) * 1 # just the derivative
            
                ### updating weights on every review ###
                self.weights_2_o += layer_2.T.dot(output_error_term) * learning_rate
                self.weights_1_2 += layer_1.T.dot(hidden2_error_term) * learning_rate
                self.weights_i_1 += layer_i.T.dot(hidden1_error_term) * learning_rate
                
                ### for training progress ###
                if abs(output_error) < 0.5:
                    correct_so_far += 1
                    
                elapsed_time = float(time.time() - start)
                progress = ((100.0 * (item+1+(i*len(self.train_reviews)))/(len(self.train_reviews)*epochs)))
                
                if progress % 5 == 0:
                    sys.stdout.write("\rProgress:" + str(progress)[:4] + "%" \
                                    + " | #Correct:" + str(correct_so_far) + "--> #Trained:" + str((item+1)+(i*len(self.train_reviews))) \
                                    + " | Training Accuracy:" + str(correct_so_far * 100.0 / (float(item+1)+(i*len(self.train_reviews))))[:4] + "%" \
                                    + " | Average Training speed per epoch: " + str(elapsed_time/(i+1))[:4] + " seconds")

                
    def run(self, review):
        
        ### create input layer ###
        layer_i = np.zeros((1, len(self.vocab_index))) 
        for word in review.split(" "):
            if word in self.vocab_index:    
                layer_i[0, self.vocab_index[word]] += 1
            
        ### FORWARD PASS ###
        layer_1 = np.dot(layer_i, self.weights_i_1)
        layer_2 = np.dot(layer_1, self.weights_1_2)
        output = self.sigmoid(np.dot(layer_2, self.weights_2_o))
        
        if output >= 0.5:
            return "POSITIVE"
        else:
            return "NEGATIVE"
                
    
    def test(self, testing_reviews, testing_labels):
        
        correct = 0

        start = time.time()
        
        ### "self.run" each testing review through the network and count how many it got correct ###
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if (pred == testing_labels[i]):
                correct += 1
            
            
            ### print out accuracy and speed ###
            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            if i == (len(testing_reviews)-1):
                sys.stdout.write("\rProgress: " + str(100 * i/float(len(testing_reviews)-1))[:4] + "%" \
                                 + "\t#Correct: " + str(correct) + "\t#Tested:" + str(i+1))
        print("")
        print("Testing Accuracy: " + str(100*correct/len(testing_reviews)) + "%")

# %%
network_v2 = SentimentNetwork(reviews[:-1000], labels[:-1000], common_cutoff = 100)
network_v2.train(learning_rate = 0.1, epochs = 5)
# Out:
#
# Epoch #1:
#
# Progress:20.0% | #Correct:15530--> #Trained:24000 | Training Accuracy:64.7% | Average Training speed per epoch: 8.15 seconds
# Epoch #2:
#
# Progress:40.0% | #Correct:33698--> #Trained:48000 | Training Accuracy:70.2% | Average Training speed per epoch: 8.15 seconds
# Epoch #3:
#
# Progress:60.0% | #Correct:52773--> #Trained:72000 | Training Accuracy:73.2% | Average Training speed per epoch: 8.22 seconds
# Epoch #4:
#
# Progress:80.0% | #Correct:72268--> #Trained:96000 | Training Accuracy:75.2% | Average Training speed per epoch: 8.32 seconds
# Epoch #5:
#
# Progress:100.% | #Correct:91937--> #Trained:120000 | Training Accuracy:76.6% | Average Training speed per epoch: 8.37 seconds

# %%
network_v2.test(reviews[-1000:], labels[-1000:])
# Out:
# Progress: 100.%	#Correct: 800	#Tested:1000
# Testing Accuracy: 80.0%

# %% [markdown]
# Wow much faster, the size of our networks vocabulary has dramatically decreased making the input and training process a lot quicker with basically the same results. We went from an average training speed per epoch of 108 seconds, to about 8 seconds per epoch.
#
#
#
# Now that we can train fast let's try to optimize the learning rate.
# With a common_cutoff of 100 and a learning rate of 0.1 and 5 epochs, we got a 80% testing accuracy.
#
# Let's see if making the learning rate 0.01 will give better results. I will bump up the epochs a little to compensate for the smaller learning rate.

# %%
network_v2 = SentimentNetwork(reviews[:-1000], labels[:-1000], common_cutoff = 100)
network_v2.train(learning_rate = 0.01, epochs = 7)
# Out:
#
# Epoch #1:
#
# Progress:10.0% | #Correct:10964--> #Trained:16800 | Training Accuracy:65.2% | Average Training speed per epoch: 5.66 seconds
# Epoch #2:
#
# Progress:25.0% | #Correct:30049--> #Trained:42000 | Training Accuracy:71.5% | Average Training speed per epoch: 7.16 seconds
# Epoch #3:
#
# Progress:40.0% | #Correct:50135--> #Trained:67200 | Training Accuracy:74.6% | Average Training speed per epoch: 7.62 seconds
# Epoch #4:
#
# Progress:55.0% | #Correct:70782--> #Trained:92400 | Training Accuracy:76.6% | Average Training speed per epoch: 7.85 seconds
# Epoch #5:
#
# Progress:70.0% | #Correct:91733--> #Trained:117600 | Training Accuracy:78.0% | Average Training speed per epoch: 8.00 seconds
# Epoch #6:
#
# Progress:85.0% | #Correct:112877--> #Trained:142800 | Training Accuracy:79.0% | Average Training speed per epoch: 8.09 seconds
# Epoch #7:
#
# Progress:100.% | #Correct:134240--> #Trained:168000 | Training Accuracy:79.9% | Average Training speed per epoch: 8.15 seconds

# %%
network_v2.test(reviews[-1000:], labels[-1000:])
# Out:
# Progress: 100.%	#Correct: 823	#Tested:1000
# Testing Accuracy: 82.3%

# %% [markdown]
# 82%, an increase. Let's see if making it even smaller to 0.001 will make a give better results.

# %%
network_v2 = SentimentNetwork(reviews[:-1000], labels[:-1000], common_cutoff = 100)
network_v2.train(learning_rate = 0.001, epochs = 7)
# Out:
#
# Epoch #1:
#
# Progress:10.0% | #Correct:10991--> #Trained:16800 | Training Accuracy:65.4% | Average Training speed per epoch: 5.66 seconds
# Epoch #2:
#
# Progress:25.0% | #Correct:30048--> #Trained:42000 | Training Accuracy:71.5% | Average Training speed per epoch: 7.08 seconds
# Epoch #3:
#
# Progress:40.0% | #Correct:50144--> #Trained:67200 | Training Accuracy:74.6% | Average Training speed per epoch: 7.57 seconds
# Epoch #4:
#
# Progress:55.0% | #Correct:70716--> #Trained:92400 | Training Accuracy:76.5% | Average Training speed per epoch: 7.81 seconds
# Epoch #5:
#
# Progress:70.0% | #Correct:91633--> #Trained:117600 | Training Accuracy:77.9% | Average Training speed per epoch: 7.95 seconds
# Epoch #6:
#
# Progress:85.0% | #Correct:112765--> #Trained:142800 | Training Accuracy:78.9% | Average Training speed per epoch: 8.04 seconds
# Epoch #7:
#
# Progress:100.% | #Correct:134104--> #Trained:168000 | Training Accuracy:79.8% | Average Training speed per epoch: 8.10 seconds

# %%
network_v2.test(reviews[-1000:], labels[-1000:])
# Out:
# Progress: 100.%	#Correct: 836	#Tested:1000
# Testing Accuracy: 83.6%

# %% [markdown]
# 83.6 percent is pretty good. Let's play around with the common_cutoff variable and try to optimize it for the best.
#
# Let's try a common_cutoff of 150:

# %%
network_v2 = SentimentNetwork(reviews[:-1000], labels[:-1000], common_cutoff = 150)
network_v2.train(learning_rate = 0.001, epochs = 7)
network_v2.test(reviews[-1000:], labels[-1000:])
# Out:
#
# Epoch #1:
#
# Progress:10.0% | #Correct:10976--> #Trained:16800 | Training Accuracy:65.3% | Average Training speed per epoch: 5.06 seconds
# Epoch #2:
#
# Progress:25.0% | #Correct:30002--> #Trained:42000 | Training Accuracy:71.4% | Average Training speed per epoch: 6.33 seconds
# Epoch #3:
#
# Progress:40.0% | #Correct:50064--> #Trained:67200 | Training Accuracy:74.5% | Average Training speed per epoch: 6.75 seconds
# Epoch #4:
#
# Progress:55.0% | #Correct:70585--> #Trained:92400 | Training Accuracy:76.3% | Average Training speed per epoch: 6.97 seconds
# Epoch #5:
#
# Progress:70.0% | #Correct:91428--> #Trained:117600 | Training Accuracy:77.7% | Average Training speed per epoch: 7.10 seconds
# Epoch #6:
#
# Progress:85.0% | #Correct:112489--> #Trained:142800 | Training Accuracy:78.7% | Average Training speed per epoch: 7.18 seconds
# Epoch #7:
#
# Progress: 100.%	#Correct: 824	#Tested:1000ed:168000 | Training Accuracy:79.6% | Average Training speed per epoch: 7.23 seconds
# Testing Accuracy: 82.4%

# %% [markdown]
# Hmmm worse results. How about a common_cutoff of 50?

# %%
network_v2 = SentimentNetwork(reviews[:-1000], labels[:-1000], common_cutoff = 50)
network_v2.train(learning_rate = 0.001, epochs = 7)
network_v2.test(reviews[-1000:], labels[-1000:])
# Out:
#
# Epoch #1:
#
# Progress:10.0% | #Correct:11001--> #Trained:16800 | Training Accuracy:65.4% | Average Training speed per epoch: 7.05 seconds
# Epoch #2:
#
# Progress:25.0% | #Correct:30079--> #Trained:42000 | Training Accuracy:71.6% | Average Training speed per epoch: 8.86 seconds
# Epoch #3:
#
# Progress:40.0% | #Correct:50204--> #Trained:67200 | Training Accuracy:74.7% | Average Training speed per epoch: 9.44 seconds
# Epoch #4:
#
# Progress:55.0% | #Correct:70842--> #Trained:92400 | Training Accuracy:76.6% | Average Training speed per epoch: 9.74 seconds
# Epoch #5:
#
# Progress:70.0% | #Correct:91836--> #Trained:117600 | Training Accuracy:78.0% | Average Training speed per epoch: 9.92 seconds
# Epoch #6:
#
# Progress:85.0% | #Correct:113072--> #Trained:142800 | Training Accuracy:79.1% | Average Training speed per epoch: 10.0 seconds
# Epoch #7:
#
# Progress: 100.%	#Correct: 824	#Tested:1000ed:168000 | Training Accuracy:80.0% | Average Training speed per epoch: 10.1 seconds
# Testing Accuracy: 82.4%

# %% [markdown]
# Same as 150. How about a common_cutoff of 50 and a LR of 0.01

# %%
network_v2 = SentimentNetwork(reviews[:-1000], labels[:-1000], common_cutoff = 50)
network_v2.train(learning_rate = 0.01, epochs = 7)
network_v2.test(reviews[-1000:], labels[-1000:])
# Out:
#
# Epoch #1:
#
# Progress:10.0% | #Correct:10992--> #Trained:16800 | Training Accuracy:65.4% | Average Training speed per epoch: 7.49 seconds
# Epoch #2:
#
# Progress:25.0% | #Correct:30108--> #Trained:42000 | Training Accuracy:71.6% | Average Training speed per epoch: 9.55 seconds
# Epoch #3:
#
# Progress:40.0% | #Correct:50272--> #Trained:67200 | Training Accuracy:74.8% | Average Training speed per epoch: 10.2 seconds
# Epoch #4:
#
# Progress:55.0% | #Correct:71006--> #Trained:92400 | Training Accuracy:76.8% | Average Training speed per epoch: 10.5 seconds
# Epoch #5:
#
# Progress:70.0% | #Correct:92029--> #Trained:117600 | Training Accuracy:78.2% | Average Training speed per epoch: 10.6 seconds
# Epoch #6:
#
# Progress:85.0% | #Correct:113280--> #Trained:142800 | Training Accuracy:79.3% | Average Training speed per epoch: 10.8 seconds
# Epoch #7:
#
# Progress: 100.%	#Correct: 847	#Tested:1000ed:168000 | Training Accuracy:80.2% | Average Training speed per epoch: 10.9 seconds
# Testing Accuracy: 84.7%

# %% [markdown]
# Ok, highest we've got so far. Let's try reducing the epochs to make sure we are at an optimal configuration.

# %%
network_v2 = SentimentNetwork(reviews[:-1000], labels[:-1000], common_cutoff = 50)
network_v2.train(learning_rate = 0.01, epochs = 5)
network_v2.test(reviews[-1000:], labels[-1000:])
# Out:
#
# Epoch #1:
#
# Progress:20.0% | #Correct:16278--> #Trained:24000 | Training Accuracy:67.8% | Average Training speed per epoch: 10.6 seconds
# Epoch #2:
#
# Progress:40.0% | #Correct:34888--> #Trained:48000 | Training Accuracy:72.6% | Average Training speed per epoch: 10.3 seconds
# Epoch #3:
#
# Progress:60.0% | #Correct:54206--> #Trained:72000 | Training Accuracy:75.2% | Average Training speed per epoch: 10.2 seconds
# Epoch #4:
#
# Progress:80.0% | #Correct:74024--> #Trained:96000 | Training Accuracy:77.1% | Average Training speed per epoch: 10.2 seconds
# Epoch #5:
#
# Progress: 100.%	#Correct: 828	#Tested:1000d:120000 | Training Accuracy:78.3% | Average Training speed per epoch: 10.2 seconds
# Testing Accuracy: 82.8%

# %% [markdown]
# With an accuracy of 84.7%, it looks like a learning rate of 0.01, 7 Epochs, and common_cutoff at 50, is the best configuration for this network.

# %% [markdown]
# # Reducing Neural Noise
#
# So far we have an accuracy of 84.7% which is pretty good. Maybe we can make our network able to perform better by reducing the amount of noise that goes through the network. Neural Noise is when the network does extra calculations with data that does not nesasarily help solve the problem at hand.

# %% [markdown]
# Let's take a look at how we input a review into our network.
#
# Right now:
# - We create an input layer the same size as our networks vocabulary
# - We set an index for that input layer for each word in the vocab
# - for/at each indice:
#   ----> input the number of times the word associated with that indice is used in the review

# %% [markdown]
# Let's look at an example input from a review:

# %%
### review #1 as input ###
example_counter = Counter()
for word in reviews[0].split(" "):
    example_counter[word] += 1

example_counter.most_common()
# Out:
# [('.', 27),
#  ('', 18),
#  ('the', 9),
#  ('to', 6),
#  ('high', 5),
#  ('i', 5),
#  ('bromwell', 4),
#  ('is', 4),
#  ('a', 4),
#  ('teachers', 4),
#  ('that', 4),
#  ('of', 4),
#  ('it', 2),
#  ('at', 2),
#  ('as', 2),
#  ('school', 2),
#  ('my', 2),
#  ('in', 2),
#  ('me', 2),
#  ('students', 2),
#  ('their', 2),
#  ('student', 2),
#  ('cartoon', 1),
#  ('comedy', 1),
#  ('ran', 1),
#  ('same', 1),
#  ('time', 1),
#  ('some', 1),
#  ('other', 1),
#  ('programs', 1),
#  ('about', 1),
#  ('life', 1),
#  ('such', 1),
#  ('years', 1),
#  ('teaching', 1),
#  ('profession', 1),
#  ('lead', 1),
#  ('believe', 1),
#  ('s', 1),
#  ('satire', 1),
#  ('much', 1),
#  ('closer', 1),
#  ('reality', 1),
#  ('than', 1),
#  ('scramble', 1),
#  ('survive', 1),
#  ('financially', 1),
#  ('insightful', 1),
#  ('who', 1),
#  ('can', 1),
#  ('see', 1),
#  ('right', 1),
#  ('through', 1),
#  ('pathetic', 1),
#  ('pomp', 1),
#  ('pettiness', 1),
#  ('whole', 1),
#  ('situation', 1),
#  ('all', 1),
#  ('remind', 1),
#  ('schools', 1),
#  ('knew', 1),
#  ('and', 1),
#  ('when', 1),
#  ('saw', 1),
#  ('episode', 1),
#  ('which', 1),
#  ('repeatedly', 1),
#  ('tried', 1),
#  ('burn', 1),
#  ('down', 1),
#  ('immediately', 1),
#  ('recalled', 1),
#  ('classic', 1),
#  ('line', 1),
#  ('inspector', 1),
#  ('m', 1),
#  ('here', 1),
#  ('sack', 1),
#  ('one', 1),
#  ('your', 1),
#  ('welcome', 1),
#  ('expect', 1),
#  ('many', 1),
#  ('adults', 1),
#  ('age', 1),
#  ('think', 1),
#  ('far', 1),
#  ('fetched', 1),
#  ('what', 1),
#  ('pity', 1),
#  ('isn', 1),
#  ('t', 1)]

# %%
### review #4 as input ###
example_counter = Counter()
for word in reviews[3].split(" "):
    example_counter[word] += 1

example_counter.most_common()
# Out:
# [('', 167),
#  ('the', 53),
#  ('of', 23),
#  ('.', 23),
#  ('a', 22),
#  ('is', 14),
#  ('to', 13),
#  ('airport', 12),
#  ('i', 12),
#  ('as', 11),
#  ('with', 11),
#  ('s', 11),
#  ('it', 10),
#  ('this', 9),
#  ('in', 8),
#  ('br', 8),
#  ('plane', 7),
#  ('t', 7),
#  ('or', 7),
#  ('out', 6),
#  ('while', 6),
#  ('but', 5),
#  ('for', 5),
#  ('not', 5),
#  ('air', 4),
#  ('time', 4),
#  ('disaster', 4),
#  ('three', 4),
#  ('have', 4),
#  ('one', 4),
#  ('just', 4),
#  ('if', 4),
#  ('are', 4),
#  ('that', 4),
#  ('little', 4),
#  ('much', 4),
#  ('there', 4),
#  ('scenes', 4),
#  ('his', 3),
#  ('also', 3),
#  ('on', 3),
#  ('by', 3),
#  ('two', 3),
#  ('they', 3),
#  ('an', 3),
#  ('films', 3),
#  ('so', 3),
#  ('has', 3),
#  ('could', 3),
#  ('great', 3),
#  ('even', 3),
#  ('film', 3),
#  ('other', 3),
#  ('oscar', 3),
#  ('winner', 3),
#  ('new', 2),
#  ('luxury', 2),
#  ('up', 2),
#  ('valuable', 2),
#  ('stevens', 2),
#  ('james', 2),
#  ('stewart', 2),
#  ('who', 2),
#  ('flying', 2),
#  ('opened', 2),
#  ('takes', 2),
#  ('off', 2),
#  ('mid', 2),
#  ('hi', 2),
#  ('chambers', 2),
#  ('oil', 2),
#  ('rig', 2),
#  ('crashing', 2),
#  ('where', 2),
#  ('sinks', 2),
#  ('right', 2),
#  ('help', 2),
#  ('was', 2),
#  ('like', 2),
#  ('can', 2),
#  ('say', 2),
#  ('any', 2),
#  ('although', 2),
#  ('far', 2),
#  ('liked', 2),
#  ('plot', 2),
#  ('see', 2),
#  ('were', 2),
#  ('another', 2),
#  ('flick', 2),
#  ('either', 2),
#  ('when', 2),
#  ('made', 2),
#  ('character', 2),
#  ('dull', 2),
#  ('lethargic', 2),
#  ('tension', 2),
#  ('minutes', 2),
#  ('been', 2),
#  ('about', 2),
#  ('george', 2),
#  ('kennedy', 2),
#  ('patroni', 2),
#  ('couple', 2),
#  ('look', 2),
#  ('extra', 2),
#  ('hour', 2),
#  ('footage', 2),
#  ('including', 2),
#  ('more', 2),
#  ('than', 2),
#  ('shame', 2),
#  ('reckon', 2),
#  ('production', 2),
#  ('looks', 2),
#  ('lee', 2),
#  ('starts', 1),
#  ('brand', 1),
#  ('loaded', 1),
#  ('paintings', 1),
#  ('such', 1),
#  ('belonging', 1),
#  ('rich', 1),
#  ('businessman', 1),
#  ('philip', 1),
#  ('them', 1),
#  ('bunch', 1),
#  ('vip', 1),
#  ('estate', 1),
#  ('preparation', 1),
#  ('being', 1),
#  ('public', 1),
#  ('museum', 1),
#  ('board', 1),
#  ('daughter', 1),
#  ('julie', 1),
#  ('kathleen', 1),
#  ('quinlan', 1),
#  ('her', 1),
#  ('son', 1),
#  ('jetliner', 1),
#  ('planned', 1),
#  ('jacked', 1),
#  ('co', 1),
#  ('pilot', 1),
#  ('robert', 1),
#  ('foxworth', 1),
#  ('accomplice', 1),
#  ('banker', 1),
#  ('monte', 1),
#  ('markham', 1),
#  ('wilson', 1),
#  ('michael', 1),
#  ('pataki', 1),
#  ('knock', 1),
#  ('passengers', 1),
#  ('crew', 1),
#  ('sleeping', 1),
#  ('gas', 1),
#  ('plan', 1),
#  ('steal', 1),
#  ('cargo', 1),
#  ('land', 1),
#  ('disused', 1),
#  ('strip', 1),
#  ('isolated', 1),
#  ('island', 1),
#  ('making', 1),
#  ('descent', 1),
#  ('almost', 1),
#  ('hits', 1),
#  ('ocean', 1),
#  ('loses', 1),
#  ('control', 1),
#  ('sending', 1),
#  ('into', 1),
#  ('sea', 1),
#  ('bottom', 1),
#  ('bang', 1),
#  ('middle', 1),
#  ('bermuda', 1),
#  ('triangle', 1),
#  ('short', 1),
#  ('supply', 1),
#  ('water', 1),
#  ('leaking', 1),
#  ('having', 1),
#  ('flown', 1),
#  ('over', 1),
#  ('miles', 1),
#  ('course', 1),
#  ('problems', 1),
#  ('mount', 1),
#  ('survivor', 1),
#  ('await', 1),
#  ('fast', 1),
#  ('running', 1),
#  ('known', 1),
#  ('under', 1),
#  ('slightly', 1),
#  ('different', 1),
#  ('tile', 1),
#  ('second', 1),
#  ('sequel', 1),
#  ('smash', 1),
#  ('hit', 1),
#  ('thriller', 1),
#  ('directed', 1),
#  ('jerry', 1),
#  ('jameson', 1),
#  ('once', 1),
#  ('again', 1),
#  ('predecessors', 1),
#  ('sort', 1),
#  ('forgotten', 1),
#  ('classic', 1),
#  ('entertaining', 1),
#  ('necessarily', 1),
#  ('reasons', 1),
#  ('seen', 1),
#  ('actually', 1),
#  ('best', 1),
#  ('my', 1),
#  ('favourite', 1),
#  ('nice', 1),
#  ('jacking', 1),
#  ('then', 1),
#  ('didn', 1),
#  ('he', 1),
#  ('sinking', 1),
#  ('maybe', 1),
#  ('makers', 1),
#  ('trying', 1),
#  ('cross', 1),
#  ('original', 1),
#  ('popular', 1),
#  ('period', 1),
#  ('poseidon', 1),
#  ('adventure', 1),
#  ('submerged', 1),
#  ('stays', 1),
#  ('until', 1),
#  ('end', 1),
#  ('stark', 1),
#  ('dilemma', 1),
#  ('facing', 1),
#  ('those', 1),
#  ('trapped', 1),
#  ('inside', 1),
#  ('suffocate', 1),
#  ('runs', 1),
#  ('drown', 1),
#  ('floods', 1),
#  ('doors', 1),
#  ('decent', 1),
#  ('idea', 1),
#  ('bad', 1),
#  ('unsympathetic', 1),
#  ('dialogue', 1),
#  ('set', 1),
#  ('pieces', 1),
#  ('real', 1),
#  ('lack', 1),
#  ('danger', 1),
#  ('suspense', 1),
#  ('means', 1),
#  ('missed', 1),
#  ('opportunity', 1),
#  ('rather', 1),
#  ('sluggish', 1),
#  ('keeps', 1),
#  ('entertained', 1),
#  ('odd', 1),
#  ('happens', 1),
#  ('after', 1),
#  ('urgency', 1),
#  ('thought', 1),
#  ('should', 1),
#  ('navy', 1),
#  ('become', 1),
#  ('involved', 1),
#  ('things', 1),
#  ('don', 1),
#  ('pick', 1),
#  ('few', 1),
#  ('shots', 1),
#  ('huge', 1),
#  ('ships', 1),
#  ('helicopters', 1),
#  ('something', 1),
#  ('lacking', 1),
#  ('here', 1),
#  ('jinxed', 1),
#  ('airline', 1),
#  ('worker', 1),
#  ('joe', 1),
#  ('back', 1),
#  ('only', 1),
#  ('gets', 1),
#  ('barely', 1),
#  ('says', 1),
#  ('anything', 1),
#  ('preferring', 1),
#  ('worried', 1),
#  ('background', 1),
#  ('home', 1),
#  ('video', 1),
#  ('theatrical', 1),
#  ('version', 1),
#  ('run', 1),
#  ('us', 1),
#  ('tv', 1),
#  ('versions', 1),
#  ('add', 1),
#  ('opening', 1),
#  ('credits', 1),
#  ('sequence', 1),
#  ('many', 1),
#  ('flashbacks', 1),
#  ('flesh', 1),
#  ('longer', 1),
#  ('rescue', 1),
#  ('discovery', 1),
#  ('dead', 1),
#  ('bodies', 1),
#  ('navigator', 1),
#  ('would', 1),
#  ('am', 1),
#  ('sure', 1),
#  ('sit', 1),
#  ('through', 1),
#  ('near', 1),
#  ('cut', 1),
#  ('expected', 1),
#  ('dated', 1),
#  ('badly', 1),
#  ('horrible', 1),
#  ('fashions', 1),
#  ('interior', 1),
#  ('design', 1),
#  ('choices', 1),
#  ('will', 1),
#  ('no', 1),
#  ('toy', 1),
#  ('model', 1),
#  ('effects', 1),
#  ('aren', 1),
#  ('along', 1),
#  ('sequels', 1),
#  ('pride', 1),
#  ('place', 1),
#  ('razzie', 1),
#  ('award', 1),
#  ('hall', 1),
#  ('think', 1),
#  ('lots', 1),
#  ('worse', 1),
#  ('harsh', 1),
#  ('action', 1),
#  ('unfortunately', 1),
#  ('pace', 1),
#  ('slow', 1),
#  ('excitement', 1),
#  ('generated', 1),
#  ('which', 1),
#  ('pretty', 1),
#  ('good', 1),
#  ('properly', 1),
#  ('values', 1),
#  ('alright', 1),
#  ('nothing', 1),
#  ('spectacular', 1),
#  ('acting', 1),
#  ('isn', 1),
#  ('jack', 1),
#  ('lemmon', 1),
#  ('said', 1),
#  ('since', 1),
#  ('mistake', 1),
#  ('star', 1),
#  ('old', 1),
#  ('frail', 1),
#  ('grant', 1),
#  ('drunk', 1),
#  ('sir', 1),
#  ('christopher', 1),
#  ('given', 1),
#  ('do', 1),
#  ('plenty', 1),
#  ('familiar', 1),
#  ('faces', 1),
#  ('too', 1),
#  ('most', 1),
#  ('orientated', 1),
#  ('ideas', 1),
#  ('behind', 1),
#  ('bit', 1),
#  ('silly', 1),
#  ('bland', 1),
#  ('direction', 1),
#  ('doesn', 1),
#  ('though', 1),
#  ('sunken', 1),
#  ('shouldn', 1),
#  ('be', 1),
#  ('boring', 1),
#  ('followed', 1),
#  ('concorde', 1)]

# %% [markdown]
# Looking at these example input's, I notice that neutral words like "the", "of", "with", "this", and "as", appear in each review often, putting high numbers for those inputs. Their numbers also vary with every review and being neutral words, don't contribute at all to prediciting the sentiment. This means our network will have to unnecessarily learn how to accomodate to this extra noise.
#
#
# The network will train faster and might even learn better if instead of inputting the number of times a word is used in a review, we only input a '1' or '0', whether or not the word occured in the review.
#
#
# From now on we will:
# - Create an input layer the same size as our networks vocabulary
# - Set an index for that input layer for each word in the vocab
# - for/at each indice:
#   ----> input a '1' if the word occurs in the review and a '0' if it doesn't
#
#
# Let's recreate our SentimentNetwork class this time with the ^new input method above.

# %%
import time                                      ##### v3 ##### 
import sys
import numpy as np
from collections import Counter

class SentimentNetwork:
    def __init__(self, train_reviews, train_labels, hidden1_nodes = 10, hidden2_nodes = 10, common_cutoff = 50):
        np.random.seed(1)
        
        ### creating total word count for all training reviews ###
        word_count = Counter()
        for review in train_reviews:
            for word in review.split(' '):
                word_count[word] += 1
        network_vocab = set()                     ####       MORE EFFICIENT AND GENERAL         ####
        for word in word_count:                   ####   <--------------                        #### 
            if word_count[word] >= common_cutoff: #### selecting common words for network vocab ####
                network_vocab.add(word)
                
        self.vocab_index = {} ### creating an index for network vocab ###
        for index,word in enumerate(network_vocab):
            self.vocab_index[word] = index
        
        ### initializing weights ###
        self.weights_i_1 = np.zeros((len(network_vocab), hidden1_nodes))
        self.weights_1_2 = np.random.normal(0.0, hidden1_nodes**-0.5, (hidden1_nodes, hidden2_nodes))
        self.weights_2_o = np.random.normal(0.0, hidden2_nodes**-0.5, (hidden2_nodes, 1))
        
        self.train_reviews = train_reviews
        self.train_labels = train_labels
        
    ### sigmoid function ###
    def sigmoid(self,x):
        
        return 1/(1.0+np.exp(-x))
        
    ### derivative of sigmoid function ###
    def sigmoid_output_derivative(self,output):
        
        return output*(1-output)
        


    def train(self, learning_rate = 0.1, epochs = 15):
            
        assert(len(self.train_reviews) == len(self.train_labels))
        
            
        correct_so_far = 0
        
        ### process labels from "POSITIVE" and "NEGATIVE" to 1 and 0 ###
        for i in range(len(self.train_labels)):
            if self.train_labels[i] == "POSITIVE":
                self.train_labels[i] = 1
            else:
                self.train_labels[i] = 0
                
        
        ### create input layer ###
        layer_i = np.zeros((1, len(self.vocab_index)))
        
        start = time.time()
        ### looping through epochs ###
        for i in range(epochs):
            print(" ")
            print("Epoch #{}:".format(i+1))
            print("")
            for item in range(len(self.train_reviews)):
            
                ### get current review ###
                creview = self.train_reviews[item]
                clabel = self.train_labels[item]    
                    
                ### update input layer for current review ###
                layer_i *= 0 
                for word in creview.split(" "):                ####        REDUCING NOISE        ####
                    if word in self.vocab_index:               #### from: "layer_i[...] *+=* 1", ####  
                        layer_i[0, self.vocab_index[word]] = 1 #### to ---> "layer_i[...] *=* 1" ####                
                
                ### FORWARD PASS ###
                layer_1 = np.dot(layer_i, self.weights_i_1)
                layer_2 = np.dot(layer_1, self.weights_1_2)
                output = self.sigmoid(np.dot(layer_2, self.weights_2_o))
            
                ### BACKPROPOGATION ###
                output_error = clabel - output
            
                output_error_term = output_error * self.sigmoid_output_derivative(output) 
            
                hidden2_error_term = output_error_term.dot(self.weights_2_o.T) * 1 # just the derivative
            
                hidden1_error_term = hidden2_error_term.dot(self.weights_1_2.T) * 1 # just the derivative
            
                ### updating weights on every review ###
                self.weights_2_o += layer_2.T.dot(output_error_term) * learning_rate
                self.weights_1_2 += layer_1.T.dot(hidden2_error_term) * learning_rate
                self.weights_i_1 += layer_i.T.dot(hidden1_error_term) * learning_rate
                
                ### for training progress ###
                if abs(output_error) < 0.5:
                    correct_so_far += 1
                    
                elapsed_time = float(time.time() - start)
                progress = ((100.0 * (item+1+(i*len(self.train_reviews)))/(len(self.train_reviews)*epochs)))
                
                if progress % 5 == 0:
                    sys.stdout.write("\rProgress:" + str(progress)[:4] + "%" \
                                    + " | #Correct:" + str(correct_so_far) + "--> #Trained:" + str((item+1)+(i*len(self.train_reviews))) \
                                    + " | Training Accuracy:" + str(correct_so_far * 100.0 / (float(item+1)+(i*len(self.train_reviews))))[:4] + "%" \
                                    + " | Average Training speed per epoch: " + str(elapsed_time/(i+1))[:4] + " seconds")

                
    def run(self, review):
        
        ### create input layer ###
        layer_i = np.zeros((1, len(self.vocab_index))) 
        for word in review.split(" "):                 ####        REDUCING NOISE        ####
            if word in self.vocab_index:               #### from: "layer_i[...] *+=* 1", ####
                layer_i[0, self.vocab_index[word]] = 1 #### to ---> "layer_i[...] *=* 1" ####
            
        ### FORWARD PASS ###
        layer_1 = np.dot(layer_i, self.weights_i_1)
        layer_2 = np.dot(layer_1, self.weights_1_2)
        output = self.sigmoid(np.dot(layer_2, self.weights_2_o))
        
        if output >= 0.5:
            return "POSITIVE"
        else:
            return "NEGATIVE"
                
    
    def test(self, testing_reviews, testing_labels):
        
        correct = 0

        start = time.time()
        
        ### "self.run" each testing review through the network and count how many it got correct ###
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if (pred == testing_labels[i]):
                correct += 1
            
            
            ### print out accuracy and speed ###
            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            if i == (len(testing_reviews)-1):
                sys.stdout.write("\rProgress: " + str(100 * i/float(len(testing_reviews)-1))[:4] + "%" \
                                 + "\t#Correct: " + str(correct) + "\t#Tested:" + str(i+1))
        print("")
        print("Testing Accuracy: " + str(100*correct/len(testing_reviews)) + "%")

# %% [markdown]
# And test it...

# %% [markdown]
# Since the network is only dealing with numbers no greater than 1, we can reduce the number of Epochs when we train the network because the network does not have to learn to accomodate to large numbers of neutral words.

# %%
network_v3 = SentimentNetwork(reviews[:-1000], labels[:-1000], common_cutoff = 50)
network_v3.train(learning_rate = 0.01, epochs = 3)
network_v3.test(reviews[-1000:], labels[-1000:])
# Out:
#
# Epoch #1:
#
# Progress:30.0% | #Correct:18157--> #Trained:21600 | Training Accuracy:84.0% | Average Training speed per epoch: 10.3 seconds
# Epoch #2:
#
# Progress:65.0% | #Correct:40607--> #Trained:46800 | Training Accuracy:86.7% | Average Training speed per epoch: 10.6 seconds
# Epoch #3:
#
# Progress: 100.%	#Correct: 856	#Tested:1000d:72000 | Training Accuracy:88.3% | Average Training speed per epoch: 9.96 seconds
# Testing Accuracy: 85.6%

# %% [markdown]
# Trying a smaller learning rate with more epochs...

# %%
#test
network_v3 = SentimentNetwork(reviews[:-1000], labels[:-1000], common_cutoff = 50)
network_v3.train(learning_rate = 0.001, epochs = 6)
network_v3.test(reviews[-1000:], labels[-1000:])
# Out:
#
# Epoch #1:
#
# Progress:15.0% | #Correct:16809--> #Trained:21600 | Training Accuracy:77.8% | Average Training speed per epoch: 7.21 seconds
# Epoch #2:
#
# Progress:30.0% | #Correct:34939--> #Trained:43200 | Training Accuracy:80.8% | Average Training speed per epoch: 7.25 seconds
# Epoch #3:
#
# Progress:50.0% | #Correct:59991--> #Trained:72000 | Training Accuracy:83.3% | Average Training speed per epoch: 8.06 seconds
# Epoch #4:
#
# Progress:65.0% | #Correct:79137--> #Trained:93600 | Training Accuracy:84.5% | Average Training speed per epoch: 7.85 seconds
# Epoch #5:
#
# Progress:80.0% | #Correct:98533--> #Trained:115200 | Training Accuracy:85.5% | Average Training speed per epoch: 7.72 seconds
# Epoch #6:
#
# Progress: 100.%	#Correct: 856	#Tested:1000ed:144000 | Training Accuracy:86.5% | Average Training speed per epoch: 8.04 seconds
# Testing Accuracy: 85.6%

# %% [markdown]
# Same results. Playing around with the configurations show that these two((LR = 0.01, epochs = 3), and (LR = 0.001, epochs = 6)) yeild the best results. This network has achieved an 85.6% testing accuracy with the added efficiency.

# %% [markdown]
# # Further Noise Reduction
#
# Let's try to see if we can optimize our network even more to solve our problem.
#
# So let's go back to how we were first framing our problem.
#
# The theory was that the network should learn which key words should matter when predicting the sentiment. We want the network to learn that words like "horrible", and "awful", should very much lean the predictions towards negative while words like "the" or "what" or "a", should not matter at all because they are neutral words. We want our network to recognize the sentiment of specifically positive and specifically negative words while learning to not give neutral words any value.
#
#
# Maybe taking the neutral words out of our network vocabulary will allow the network to learn better because now it does not have to accomodate to as much noise? Or, maybe words that seem neutral to us that occur a lot aren't really neutral, and do have a lean towards one sentiment depending on how they are used.
#
#
# So let's go back to our positive to negative word ratios to try and validate this theory.
# Let's first take a look at the words with the most positive sentiments and words with the most negative sentiments and try to see at which P/N-ratio does the sentiment of the words start not mattering anymore(they become more neutral).
#
# (Remember "PN_ratios" is a dictionary that contains a ratio for every word found in the training reviews of how much a word appears in reviews labeled positive over how much that word appears in reviews labeled negative)

# %%
PN_ratios.most_common()[:30]
# Out:
# [('paulie', 4.7706846244656651),
#  ('edie', 4.6913478822291435),
#  ('felix', 3.3758795736778655),
#  ('polanski', 3.0056826044071592),
#  ('matthau', 2.924504764265623),
#  ('victoria', 2.7500144002012421),
#  ('mildred', 2.7362210780689065),
#  ('gandhi', 2.6567569067146595),
#  ('flawless', 2.5563656137701454),
#  ('superbly', 2.3470368555648795),
#  ('perfection', 2.2284771208403238),
#  ('astaire', 2.2141741356499924),
#  ('voight', 2.1102132003465894),
#  ('captures', 2.0794415416798357),
#  ('wonderfully', 2.0485643031153966),
#  ('brosnan', 2.0193376176101303),
#  ('powell', 2.0175661379617482),
#  ('lily', 1.9810014688665833),
#  ('bakshi', 1.9636097261547143),
#  ('lincoln', 1.9459101490553132),
#  ('lemmon', 1.9148195619852821),
#  ('breathtaking', 1.8925641683500207),
#  ('refreshing', 1.891548939836426),
#  ('bourne', 1.8870696490323797),
#  ('flynn', 1.8484548129046001),
#  ('homer', 1.8382794848629478),
#  ('soccer', 1.8268507890393251),
#  ('delightful', 1.8262456452992242),
#  ('andrews', 1.8230120127321594),
#  ('elvira', 1.7841548698428356)]

# %%
list(reversed(PN_ratios.most_common()))[:30]
# Out:
# [('boll', -4.962844630259907),
#  ('uwe', -4.6151205168412597),
#  ('seagal', -3.6375861597263857),
#  ('unwatchable', -3.2484346271097451),
#  ('stinker', -3.1986731175506815),
#  ('mst', -2.9444389791664407),
#  ('incoherent', -2.9292871741458382),
#  ('unfunny', -2.6882475738060303),
#  ('waste', -2.6186484579840514),
#  ('blah', -2.5649493574615367),
#  ('horrid', -2.4756042571256867),
#  ('pointless', -2.4531579514734201),
#  ('atrocious', -2.4203681286504293),
#  ('redeeming', -2.3648889763302003),
#  ('prom', -2.3513752571634776),
#  ('drivel', -2.338303175596125),
#  ('lousy', -2.3025850929940455),
#  ('worst', -2.2865847516476046),
#  ('laughable', -2.2617630984737906),
#  ('awful', -2.2265521924307397),
#  ('poorly', -2.2192034840549946),
#  ('wasting', -2.1972245773362196),
#  ('remotely', -2.1913594578838214),
#  ('existent', -2.0724728723637424),
#  ('boredom', -1.9870682215488209),
#  ('miserably', -1.9832976811269336),
#  ('sucks', -1.9830278120118159),
#  ('lame', -1.9802348915963879),
#  ('uninspired', -1.9740810260220096),
#  ('insult', -1.9730120788331045)]

# %% [markdown]
# Looking at the positive ratios, I see that at around a ratio of 0.35--->0, the words start getting more and more neutral. Same goes for the negative ratios, at around -0.35--->0, the words start getting more neutral.
#
# The best way to really see where the neutral words are all located is by plotting these ratios out.

# %%
from bokeh.models import ColumnDataSource, LabelSet
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="92a5b551-ece7-49cf-9c93-314118a3c2c1">Loading BokehJS ...</span>
#     </div>

# %%
hist, edges = np.histogram(list(map(lambda x:x[1],PN_ratios.most_common())), density=True, bins=100, normed=False)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="Positive to Negative Affinity Distribution")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="b6ec80a0-9a67-44fa-b5aa-ff1f5b173e46"></div>
# </div>

# %% [markdown]
# In the plot we can see that there is this huge chunk of neutral words that appear way more often then words with a stronger sentiment.
#
# Let's try to optimize our network by creating a new argument for our network, "polarity_cutoff". From now on, a word will only get added to our vocabulary if the absolute value of its positive to negative ratio is greater then the value of polarity_cutoff.

# %%
import time                                      ##### v4 ##### 
import sys
import numpy as np
from collections import Counter

class SentimentNetwork:
    def __init__(self, train_reviews, train_labels, hidden1_nodes = 10, hidden2_nodes = 10, common_cutoff = 50, polarity_cutoff = 0.5):
        np.random.seed(1)
        
        #### FURTHER NOISE REDUCTION ####
        ####   CREATING PN_ratios    ####
        P_count = Counter()
        N_count = Counter()
        
        total_word_count = Counter()
        for i in range(len(train_reviews)):
            for word in train_reviews[i].split(' '):
                if(train_labels[i] == 'POSITIVE'):       
                    P_count[word] += 1
                    total_word_count[word] += 1
                if(train_labels[i] == 'NEGATIVE'):
                    N_count[word] += 1
                    total_word_count[word] += 1
                                                              ####        : FURTHER NOISE REDUCTION :          ####
        PN_ratios = {}                                        ####                                             #### 
        network_vocab = set()                                 ####  Only adding words to the networks vocab if ####
        for word in total_word_count:                         #### the absolute value of P/N ratio is greater  #### 
            if total_word_count[word] >= common_cutoff:       ####   than "polarity_cutoff" AND, if the word   ####  
                if N_count[word] == None or N_count[word] == 0:  # appears in all of the training reviews more ####    
                    PN_ratios[word] = float(P_count[word])    #### "than common_cutoff" times                  ####
                else:
                    PN_ratios[word] = float(P_count[word]) / N_count[word]
        
        for word in PN_ratios:
            if PN_ratios[word] == 0:
                network_vocab.add(word)
            else:  
                if abs(np.log(PN_ratios[word])) >= polarity_cutoff:
                    network_vocab.add(word)

        self.vocab_index = {} ### creating an index for network vocab ###
        for index,word in enumerate(network_vocab):
            self.vocab_index[word] = index
        
        ### initializing weights ###
        self.weights_i_1 = np.zeros((len(network_vocab), hidden1_nodes))
        self.weights_1_2 = np.random.normal(0.0, hidden1_nodes**-0.5, (hidden1_nodes, hidden2_nodes))
        self.weights_2_o = np.random.normal(0.0, hidden2_nodes**-0.5, (hidden2_nodes, 1))
        
        self.train_reviews = train_reviews
        self.train_labels = train_labels
        
    ### sigmoid function ###
    def sigmoid(self,x):
        
        return 1/(1.0+np.exp(-x))
        
    ### derivative of sigmoid function ###
    def sigmoid_output_derivative(self,output):
        
        return output*(1-output)
        


    def train(self, learning_rate = 0.1, epochs = 15):
            
        assert(len(self.train_reviews) == len(self.train_labels))
        
            
        correct_so_far = 0
        
        ### process labels from "POSITIVE" and "NEGATIVE" to 1 and 0 ###
        for i in range(len(self.train_labels)):
            if self.train_labels[i] == "POSITIVE":
                self.train_labels[i] = 1
            else:
                self.train_labels[i] = 0
                
        
        ### create input layer ###
        layer_i = np.zeros((1, len(self.vocab_index)))
        
        start = time.time()
        ### looping through epochs ###
        for i in range(epochs):
            print(" ")
            print("Epoch #{}:".format(i+1))
            print("")
            for item in range(len(self.train_reviews)):
            
                ### get current review ###
                creview = self.train_reviews[item]
                clabel = self.train_labels[item]    
                    
                ### update input layer for current review ###
                layer_i *= 0 
                for word in creview.split(" "):                ####        REDUCING NOISE        ####
                    if word in self.vocab_index:               #### from: "layer_i[...] *+=* 1", ####  
                        layer_i[0, self.vocab_index[word]] = 1 #### to ---> "layer_i[...] *=* 1" ####                
                
                ### FORWARD PASS ###
                layer_1 = np.dot(layer_i, self.weights_i_1)
                layer_2 = np.dot(layer_1, self.weights_1_2)
                output = self.sigmoid(np.dot(layer_2, self.weights_2_o))
            
                ### BACKPROPOGATION ###
                output_error = clabel - output
            
                output_error_term = output_error * self.sigmoid_output_derivative(output) 
            
                hidden2_error_term = output_error_term.dot(self.weights_2_o.T) * 1 # just the derivative
            
                hidden1_error_term = hidden2_error_term.dot(self.weights_1_2.T) * 1 # just the derivative
            
                ### updating weights on every review ###
                self.weights_2_o += layer_2.T.dot(output_error_term) * learning_rate
                self.weights_1_2 += layer_1.T.dot(hidden2_error_term) * learning_rate
                self.weights_i_1 += layer_i.T.dot(hidden1_error_term) * learning_rate
                
                ### for training progress ###
                if abs(output_error) < 0.5:
                    correct_so_far += 1
                    
                elapsed_time = float(time.time() - start)
                progress = ((100.0 * (item+1+(i*len(self.train_reviews)))/(len(self.train_reviews)*epochs)))
                
                if progress % 5 == 0:
                    sys.stdout.write("\rProgress:" + str(progress)[:4] + "%" \
                                    + " | #Correct:" + str(correct_so_far) + "--> #Trained:" + str((item+1)+(i*len(self.train_reviews))) \
                                    + " | Training Accuracy:" + str(correct_so_far * 100.0 / (float(item+1)+(i*len(self.train_reviews))))[:4] + "%" \
                                    + " | Average Training speed per epoch: " + str(elapsed_time/(i+1))[:4] + " seconds")

                
    def run(self, review):
        
        ### create input layer ###
        layer_i = np.zeros((1, len(self.vocab_index))) 
        for word in review.split(" "):                 ####        REDUCING NOISE        ####
            if word in self.vocab_index:               #### from: "layer_i[...] *+=* 1", ####
                layer_i[0, self.vocab_index[word]] = 1 #### to ---> "layer_i[...] *=* 1" ####
            
        ### FORWARD PASS ###
        layer_1 = np.dot(layer_i, self.weights_i_1)
        layer_2 = np.dot(layer_1, self.weights_1_2)
        output = self.sigmoid(np.dot(layer_2, self.weights_2_o))
        
        if output >= 0.5:
            return "POSITIVE"
        else:
            return "NEGATIVE"
                
    
    def test(self, testing_reviews, testing_labels):
        
        correct = 0

        start = time.time()
        
        ### "self.run" each testing review through the network and count how many it got correct ###
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if (pred == testing_labels[i]):
                correct += 1
            
            
            ### print out accuracy and speed ###
            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            if i == (len(testing_reviews)-1):
                sys.stdout.write("\rProgress: " + str(100 * i/float(len(testing_reviews)-1))[:4] + "%" \
                                 + "\t#Correct: " + str(correct) + "\t#Tested:" + str(i+1))
        print("")
        print("Testing Accuracy: " + str(100*correct/len(testing_reviews)) + "%")

# %% [markdown]
# Let's play around with the polarity_cutoff we'll start at 0.3

# %%
network_v4 = SentimentNetwork(reviews[:-1000], labels[:-1000], common_cutoff = 50, polarity_cutoff = 0.3)
network_v4.train(learning_rate = 0.001, epochs = 6)
network_v4.test(reviews[-1000:], labels[-1000:])
# Out:
#
# Epoch #1:
#
# Progress:15.0% | #Correct:17241--> #Trained:21600 | Training Accuracy:79.8% | Average Training speed per epoch: 4.63 seconds
# Epoch #2:
#
# Progress:30.0% | #Correct:35269--> #Trained:43200 | Training Accuracy:81.6% | Average Training speed per epoch: 4.81 seconds
# Epoch #3:
#
# Progress:50.0% | #Correct:60077--> #Trained:72000 | Training Accuracy:83.4% | Average Training speed per epoch: 5.44 seconds
# Epoch #4:
#
# Progress:65.0% | #Correct:78990--> #Trained:93600 | Training Accuracy:84.3% | Average Training speed per epoch: 5.25 seconds
# Epoch #5:
#
# Progress:80.0% | #Correct:98111--> #Trained:115200 | Training Accuracy:85.1% | Average Training speed per epoch: 5.15 seconds
# Epoch #6:
#
# Progress: 100.%	#Correct: 854	#Tested:1000ed:144000 | Training Accuracy:86.0% | Average Training speed per epoch: 5.41 seconds
# Testing Accuracy: 85.4%

# %% [markdown]
# Hmm results are worse. Let's try a little higher 0.5

# %%
network_v4 = SentimentNetwork(reviews[:-1000], labels[:-1000], common_cutoff = 50, polarity_cutoff = 0.5)
network_v4.train(learning_rate = 0.001, epochs = 6)
network_v4.test(reviews[-1000:], labels[-1000:])
# Out:
#
# Epoch #1:
#
# Progress:15.0% | #Correct:17598--> #Trained:21600 | Training Accuracy:81.4% | Average Training speed per epoch: 6.81 seconds
# Epoch #2:
#
# Progress:30.0% | #Correct:35549--> #Trained:43200 | Training Accuracy:82.2% | Average Training speed per epoch: 6.51 seconds
# Epoch #3:
#
# Progress:50.0% | #Correct:60112--> #Trained:72000 | Training Accuracy:83.4% | Average Training speed per epoch: 6.18 seconds
# Epoch #4:
#
# Progress:65.0% | #Correct:78874--> #Trained:93600 | Training Accuracy:84.2% | Average Training speed per epoch: 5.58 seconds
# Epoch #5:
#
# Progress:80.0% | #Correct:97739--> #Trained:115200 | Training Accuracy:84.8% | Average Training speed per epoch: 5.23 seconds
# Epoch #6:
#
# Progress: 100.%	#Correct: 836	#Tested:1000ed:144000 | Training Accuracy:85.5% | Average Training speed per epoch: 5.20 seconds
# Testing Accuracy: 83.6%

# %% [markdown]
# Wrong direction Let's move polarity cutoff to 0.1

# %%
network_v4 = SentimentNetwork(reviews[:-1000], labels[:-1000], common_cutoff = 50, polarity_cutoff = 0.1)
network_v4.train(learning_rate = 0.001, epochs = 6)
network_v4.test(reviews[-1000:], labels[-1000:])
# Out:
#
# Epoch #1:
#
# Progress:15.0% | #Correct:16859--> #Trained:21600 | Training Accuracy:78.0% | Average Training speed per epoch: 6.28 seconds
# Epoch #2:
#
# Progress:30.0% | #Correct:34897--> #Trained:43200 | Training Accuracy:80.7% | Average Training speed per epoch: 1087 seconds
# Epoch #3:
#
# Progress:50.0% | #Correct:59864--> #Trained:72000 | Training Accuracy:83.1% | Average Training speed per epoch: 728. seconds
# Epoch #4:
#
# Progress:65.0% | #Correct:78952--> #Trained:93600 | Training Accuracy:84.3% | Average Training speed per epoch: 547. seconds
# Epoch #5:
#
# Progress:80.0% | #Correct:98303--> #Trained:115200 | Training Accuracy:85.3% | Average Training speed per epoch: 439. seconds
# Epoch #6:
#
# Progress: 100.%	#Correct: 860	#Tested:1000ed:144000 | Training Accuracy:86.3% | Average Training speed per epoch: 367. seconds
# Testing Accuracy: 86.0%

# %%
network_v4 = SentimentNetwork(reviews[:-1000], labels[:-1000], common_cutoff = 50, polarity_cutoff = 0.1)
network_v4.train(learning_rate = 0.01, epochs = 3)
network_v4.test(reviews[-1000:], labels[-1000:])
# Out:
#
# Epoch #1:
#
# Progress:30.0% | #Correct:18347--> #Trained:21600 | Training Accuracy:84.9% | Average Training speed per epoch: 6.69 seconds
# Epoch #2:
#
# Progress:65.0% | #Correct:40862--> #Trained:46800 | Training Accuracy:87.3% | Average Training speed per epoch: 7.43 seconds
# Epoch #3:
#
# Progress: 100.%	#Correct: 855	#Tested:1000d:72000 | Training Accuracy:88.7% | Average Training speed per epoch: 7.32 seconds
# Testing Accuracy: 85.5%

# %% [markdown]
# # After optimization, with a learning rate of 0.001, 6 epochs, common_cutoff of 50, and a polarity_cutoff of 0.1, our network is able to achieve 86% accuracy on the test set. Awesome, that is awesome.
